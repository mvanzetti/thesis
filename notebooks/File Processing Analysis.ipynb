# %% [markdown]
# ## ENCODE APIs

# %%
import json
import urllib.request
import requests
from pandas.io.json import json_normalize

# %%
headers = {'accept': 'application/json'}
main_url = "https://www.encodeproject.org"
search_url = main_url + "/search/?type=Annotation&annotation_type=enhancer-like+regions&frame=object&limit=all"

response = requests.get(search_url, headers=headers)
response_json_dict = response.json()

graph = response_json_dict["@graph"]

# %%
row_df = json_normalize(graph[0])
assembly_list = row_df.get_value(0, "assembly")
if len(assembly_list) > 0:
    row_df['assembly'] = assembly_list[0]
row_df
# Out:
#                          @id                                 @type  \
# 0  /annotations/ENCSR783FDB/  [Annotation, FileSet, Dataset, Item]
#
#      accession                                            aliases  \
# 0  ENCSR783FDB  [zhiping-weng:v3-enhancer-like-dnase-only-ENCS...
#
#   alternate_accessions        annotation_type assembly            award  \
# 0                   []  enhancer-like regions     hg19  /awards/ENCODE/
#
#   biosample_synonyms biosample_term_id                  ...                   \
# 0                 []        CL:0002618                  ...
#
#   related_files revoked_files schema_version    status  \
# 0            []            []              9  released
#
#                                    submitted_by superseded_by supersedes  \
# 0  /users/ef309f6b-c671-44c8-a33d-3850bd14fe63/            []         []
#
#            system_slims targets                                  uuid
# 0  [circulatory system]      []  a704722a-63b7-4d7e-aaf1-ce8b6bea92a6
#
# [1 rows x 39 columns]

# %% [markdown]
# ## Annotation files additional info

# %%
import pandas as pd
import os
from pybedtools import BedTool

# %%
file_list_name = '/Users/manuel/development/thesis/download/ENCODE/enhancer-like-bed_refs.csv'
annotation_df = pd.read_csv(file_list_name, sep='\t', index_col='index')

# %%
annotation_df.T
# Out:
# index                                                               0    \
# accession                                                   ENCSR783FDB
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               1    \
# accession                                                   ENCSR312DDF
# assembly                                               ['mm10-minimal']
# biosample_term_id                                        UBERON:0000948
# biosample_term_name                                               heart
# biosample_type                                                   tissue
# description           Enhancer-like regions using H3K27ac-only for h...
# developmental_slims                                        ['mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                   ['heart']
# organism                                                            NaN
# system_slims                                     ['circulatory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               2    \
# accession                                                   ENCSR960QES
# assembly                                               ['mm10-minimal']
# biosample_term_id                                        UBERON:0001891
# biosample_term_name                                            midbrain
# biosample_type                                                   tissue
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                   ['brain']
# organism                                                            NaN
# system_slims                                 ['central nervous system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               3    \
# accession                                                   ENCSR615QPD
# assembly                                               ['mm10-minimal']
# biosample_term_id                                        UBERON:0002107
# biosample_term_name                                               liver
# biosample_type                                                   tissue
# description           Enhancer-like regions using H3K27ac-only for l...
# developmental_slims                                        ['endoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                   ['liver']
# organism                                                            NaN
# system_slims                   ['endocrine system', 'digestive system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               4    \
# accession                                                   ENCSR522DOY
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002586
# biosample_term_name                     retinal pigment epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for ret...
# developmental_slims                                        ['ectoderm']
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                     ['eye']
# organism                                              /organisms/human/
# system_slims                                         ['sensory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               5    \
# accession                                                   ENCSR765XEI
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002518
# biosample_term_name                              kidney epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for kid...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                  ['kidney']
# organism                                              /organisms/human/
# system_slims                                       ['excretory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               6    \
# accession                                                   ENCSR385UEZ
# assembly                                                       ['hg19']
# biosample_term_id                                           NTR:0000711
# biosample_term_name                              neural progenitor cell
# biosample_type                            in vitro differentiated cells
# description           Enhancer-like regions using DNase-only for neu...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                          []
# organism                                              /organisms/human/
# system_slims                                                         []
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               7    \
# accession                                                   ENCSR891WXH
# assembly                                                       ['hg19']
# biosample_term_id                                           EFO:0002796
# biosample_term_name                                              Jurkat
# biosample_type                                   immortalized cell line
# description           Enhancer-like regions using DNase-only for Jurkat
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                          []
# organism                                              /organisms/human/
# system_slims                                                         []
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               8    \
# accession                                                   ENCSR359JDI
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002188
# biosample_term_name                         glomerular endothelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for glo...
# developmental_slims                                        ['mesoderm']
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                  ['kidney']
# organism                                              /organisms/human/
# system_slims                                       ['excretory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               9    \
# accession                                                   ENCSR918NER
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002552
# biosample_term_name                               fibroblast of gingiva
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for fib...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                   ['mouth']
# organism                                              /organisms/human/
# system_slims                                       ['digestive system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                       ...                          \
# accession                                   ...
# assembly                                    ...
# biosample_term_id                           ...
# biosample_term_name                         ...
# biosample_type                              ...
# description                                 ...
# developmental_slims                         ...
# encyclopedia_version                        ...
# month_released                              ...
# organ_slims                                 ...
# organism                                    ...
# system_slims                                ...
# bed_filename                                ...
# bed_filepath                                ...
#
# index                                                               427  \
# accession                                                   ENCSR643FZD
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0000492
# biosample_term_name                          CD4-positive helper T cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for P...
# developmental_slims                            ['endoderm', 'mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                          []
# organism                                                            NaN
# system_slims                                          ['immune system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               428  \
# accession                                                   ENCSR516DXQ
# assembly                                                       ['hg19']
# biosample_term_id                                        UBERON:0000945
# biosample_term_name                                             stomach
# biosample_type                                                   tissue
# description           Enhancer-like regions using H3K27ac-only for G...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                 ['stomach']
# organism                                                            NaN
# system_slims                                       ['digestive system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               429  \
# accession                                                   ENCSR807AHZ
# assembly                                                       ['hg19']
# biosample_term_id                                        UBERON:0001043
# biosample_term_name                                           esophagus
# biosample_type                                                   tissue
# description           Enhancer-like regions using H3K27ac-only for E...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                               ['esophagus']
# organism                                                            NaN
# system_slims                                       ['digestive system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               430  \
# accession                                                   ENCSR977MRM
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0000236
# biosample_term_name                                              B cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                          []
# organism                                              /organisms/human/
# system_slims                                          ['immune system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               431  \
# accession                                                   ENCSR374MQO
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for U...
# developmental_slims                                        ['mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                            ['blood vessel']
# organism                                                            NaN
# system_slims                                     ['circulatory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               432  \
# accession                                                   ENCSR750HZU
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0000492
# biosample_term_name                          CD4-positive helper T cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for P...
# developmental_slims                            ['endoderm', 'mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                          []
# organism                                                            NaN
# system_slims                                          ['immune system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               433  \
# accession                                                   ENCSR226GOY
# assembly                                                       ['hg19']
# biosample_term_id                                        UBERON:0002369
# biosample_term_name                                       adrenal gland
# biosample_type                                                   tissue
# description           Enhancer-like regions using H3K27ac-only for F...
# developmental_slims                            ['ectoderm', 'mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                           ['adrenal gland']
# organism                                                            NaN
# system_slims                                       ['endocrine system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               434  \
# accession                                                   ENCSR936YWW
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for M...
# developmental_slims                                        ['ectoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                           ['mammary gland']
# organism                                                            NaN
# system_slims                                    ['integumental system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               435  \
# accession                                                   ENCSR122FDL
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0000492
# biosample_term_name                          CD4-positive helper T cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for P...
# developmental_slims                            ['endoderm', 'mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                          []
# organism                                                            NaN
# system_slims                                          ['immune system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               436
# accession                                                   ENCSR277LBT
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0000084
# biosample_term_name                                              T-cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for P...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                          []
# organism                                                            NaN
# system_slims                                          ['immune system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# [14 rows x 437 columns]

# %%
bed_filepath = annotation_df.get_value(0, 'bed_filepath')
annotation_file = BedTool(bed_filepath)

# %%
bed_df = annotation_file.to_dataframe()

# %%
bed_df.T
# Out:
#                                    0                             1      \
# chrom                               chr1                          chr8
# start                           91852606                      70602170
# end                             91853249                      70602736
# name        Distal-Prediction-Boundary-1  Distal-Prediction-Boundary-2
# score                                  1                             1
# strand                                 .                             .
# thickStart                      91852820                      70602340
# thickEnd                        91852970                      70602490
# itemRgb                      255,235,200                   255,235,200
#
#                                    2                             3      \
# chrom                               chr8                         chr11
# start                          100507654                      85194851
# end                            100508251                      85195324
# name        Distal-Prediction-Boundary-3  Distal-Prediction-Boundary-4
# score                                  1                             1
# strand                                 .                             .
# thickStart                     100508060                      85195040
# thickEnd                       100508210                      85195190
# itemRgb                      255,235,200                   255,235,200
#
#                                    4                             5      \
# chrom                              chr10                         chr17
# start                           42379744                      33477932
# end                             42380535                      33478557
# name        Distal-Prediction-Boundary-5  Distal-Prediction-Boundary-6
# score                                  1                             1
# strand                                 .                             .
# thickStart                      42379780                      33478160
# thickEnd                        42379930                      33478310
# itemRgb                      255,235,200                   255,235,200
#
#                                    6                             7      \
# chrom                               chr1                         chr19
# start                          156186019                      36066304
# end                            156186829                      36066961
# name        Distal-Prediction-Boundary-7  Distal-Prediction-Boundary-8
# score                                  1                             1
# strand                                 .                             .
# thickStart                     156186420                      36066480
# thickEnd                       156186570                      36066630
# itemRgb                      255,235,200                   255,235,200
#
#                                    8                              9      \
# chrom                              chr10                           chr4
# start                           42393239                       49151622
# end                             42393622                       49151945
# name        Distal-Prediction-Boundary-9  Distal-Prediction-Boundary-10
# score                                  1                              1
# strand                                 .                              .
# thickStart                      42393320                       49151700
# thickEnd                        42393470                       49151850
# itemRgb                      255,235,200                    255,235,200
#
#                       ...                                  71372  \
# chrom                 ...                                   chr2
# start                 ...                               62376980
# end                   ...                               62377130
# name                  ...              Proximal-Prediction-15682
# score                 ...                                      1
# strand                ...                                      .
# thickStart            ...                               62376980
# thickEnd              ...                               62377130
# itemRgb               ...                                250,0,0
#
#                                 71373                      71374  \
# chrom                           chr17                      chr16
# start                        74394140                   30640120
# end                          74394290                   30640270
# name        Proximal-Prediction-15683  Proximal-Prediction-15684
# score                               1                          1
# strand                              .                          .
# thickStart                   74394140                   30640120
# thickEnd                     74394290                   30640270
# itemRgb                       250,0,0                    250,0,0
#
#                                 71375                      71376  \
# chrom                           chr19                      chr12
# start                        48201440                   66429220
# end                          48201590                   66429370
# name        Proximal-Prediction-15685  Proximal-Prediction-15686
# score                               1                          1
# strand                              .                          .
# thickStart                   48201440                   66429220
# thickEnd                     48201590                   66429370
# itemRgb                       250,0,0                    250,0,0
#
#                                 71377                      71378  \
# chrom                           chr16                       chr1
# start                        27190940                  159147200
# end                          27191090                  159147350
# name        Proximal-Prediction-15687  Proximal-Prediction-15688
# score                               1                          1
# strand                              .                          .
# thickStart                   27190940                  159147200
# thickEnd                     27191090                  159147350
# itemRgb                       250,0,0                    250,0,0
#
#                                 71379                      71380  \
# chrom                           chr14                       chr7
# start                        50154920                  100702720
# end                          50155070                  100702870
# name        Proximal-Prediction-15689  Proximal-Prediction-15690
# score                               1                          1
# strand                              .                          .
# thickStart                   50154920                  100702720
# thickEnd                     50155070                  100702870
# itemRgb                       250,0,0                    250,0,0
#
#                                 71381
# chrom                           chr19
# start                        10812020
# end                          10812170
# name        Proximal-Prediction-15691
# score                               1
# strand                              .
# thickStart                   10812020
# thickEnd                     10812170
# itemRgb                       250,0,0
#
# [9 rows x 71382 columns]

# %%
import ast
field_val = annotation_df.get_value(0, 'assembly')
assembly_list = ast.literal_eval(field_val)
assembly_list[0]
# Out:
# 'hg19'

# %%
annotation_df.T
# Out:
# index                                                               0    \
# accession                                                   ENCSR783FDB
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               1    \
# accession                                                   ENCSR312DDF
# assembly                                               ['mm10-minimal']
# biosample_term_id                                        UBERON:0000948
# biosample_term_name                                               heart
# biosample_type                                                   tissue
# description           Enhancer-like regions using H3K27ac-only for h...
# developmental_slims                                        ['mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                   ['heart']
# organism                                                            NaN
# system_slims                                     ['circulatory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               2    \
# accession                                                   ENCSR960QES
# assembly                                               ['mm10-minimal']
# biosample_term_id                                        UBERON:0001891
# biosample_term_name                                            midbrain
# biosample_type                                                   tissue
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                   ['brain']
# organism                                                            NaN
# system_slims                                 ['central nervous system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               3    \
# accession                                                   ENCSR615QPD
# assembly                                               ['mm10-minimal']
# biosample_term_id                                        UBERON:0002107
# biosample_term_name                                               liver
# biosample_type                                                   tissue
# description           Enhancer-like regions using H3K27ac-only for l...
# developmental_slims                                        ['endoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                   ['liver']
# organism                                                            NaN
# system_slims                   ['endocrine system', 'digestive system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               4    \
# accession                                                   ENCSR522DOY
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002586
# biosample_term_name                     retinal pigment epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for ret...
# developmental_slims                                        ['ectoderm']
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                     ['eye']
# organism                                              /organisms/human/
# system_slims                                         ['sensory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               5    \
# accession                                                   ENCSR765XEI
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002518
# biosample_term_name                              kidney epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for kid...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                  ['kidney']
# organism                                              /organisms/human/
# system_slims                                       ['excretory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               6    \
# accession                                                   ENCSR385UEZ
# assembly                                                       ['hg19']
# biosample_term_id                                           NTR:0000711
# biosample_term_name                              neural progenitor cell
# biosample_type                            in vitro differentiated cells
# description           Enhancer-like regions using DNase-only for neu...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                          []
# organism                                              /organisms/human/
# system_slims                                                         []
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               7    \
# accession                                                   ENCSR891WXH
# assembly                                                       ['hg19']
# biosample_term_id                                           EFO:0002796
# biosample_term_name                                              Jurkat
# biosample_type                                   immortalized cell line
# description           Enhancer-like regions using DNase-only for Jurkat
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                          []
# organism                                              /organisms/human/
# system_slims                                                         []
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               8    \
# accession                                                   ENCSR359JDI
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002188
# biosample_term_name                         glomerular endothelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for glo...
# developmental_slims                                        ['mesoderm']
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                  ['kidney']
# organism                                              /organisms/human/
# system_slims                                       ['excretory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               9    \
# accession                                                   ENCSR918NER
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002552
# biosample_term_name                               fibroblast of gingiva
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for fib...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                   ['mouth']
# organism                                              /organisms/human/
# system_slims                                       ['digestive system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                       ...                          \
# accession                                   ...
# assembly                                    ...
# biosample_term_id                           ...
# biosample_term_name                         ...
# biosample_type                              ...
# description                                 ...
# developmental_slims                         ...
# encyclopedia_version                        ...
# month_released                              ...
# organ_slims                                 ...
# organism                                    ...
# system_slims                                ...
# bed_filename                                ...
# bed_filepath                                ...
#
# index                                                               427  \
# accession                                                   ENCSR643FZD
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0000492
# biosample_term_name                          CD4-positive helper T cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for P...
# developmental_slims                            ['endoderm', 'mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                          []
# organism                                                            NaN
# system_slims                                          ['immune system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               428  \
# accession                                                   ENCSR516DXQ
# assembly                                                       ['hg19']
# biosample_term_id                                        UBERON:0000945
# biosample_term_name                                             stomach
# biosample_type                                                   tissue
# description           Enhancer-like regions using H3K27ac-only for G...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                 ['stomach']
# organism                                                            NaN
# system_slims                                       ['digestive system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               429  \
# accession                                                   ENCSR807AHZ
# assembly                                                       ['hg19']
# biosample_term_id                                        UBERON:0001043
# biosample_term_name                                           esophagus
# biosample_type                                                   tissue
# description           Enhancer-like regions using H3K27ac-only for E...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                               ['esophagus']
# organism                                                            NaN
# system_slims                                       ['digestive system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               430  \
# accession                                                   ENCSR977MRM
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0000236
# biosample_term_name                                              B cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                          []
# organism                                              /organisms/human/
# system_slims                                          ['immune system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               431  \
# accession                                                   ENCSR374MQO
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for U...
# developmental_slims                                        ['mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                            ['blood vessel']
# organism                                                            NaN
# system_slims                                     ['circulatory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               432  \
# accession                                                   ENCSR750HZU
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0000492
# biosample_term_name                          CD4-positive helper T cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for P...
# developmental_slims                            ['endoderm', 'mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                          []
# organism                                                            NaN
# system_slims                                          ['immune system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               433  \
# accession                                                   ENCSR226GOY
# assembly                                                       ['hg19']
# biosample_term_id                                        UBERON:0002369
# biosample_term_name                                       adrenal gland
# biosample_type                                                   tissue
# description           Enhancer-like regions using H3K27ac-only for F...
# developmental_slims                            ['ectoderm', 'mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                           ['adrenal gland']
# organism                                                            NaN
# system_slims                                       ['endocrine system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               434  \
# accession                                                   ENCSR936YWW
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for M...
# developmental_slims                                        ['ectoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                           ['mammary gland']
# organism                                                            NaN
# system_slims                                    ['integumental system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               435  \
# accession                                                   ENCSR122FDL
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0000492
# biosample_term_name                          CD4-positive helper T cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for P...
# developmental_slims                            ['endoderm', 'mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                          []
# organism                                                            NaN
# system_slims                                          ['immune system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# index                                                               436
# accession                                                   ENCSR277LBT
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0000084
# biosample_term_name                                              T-cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for P...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                          []
# organism                                                            NaN
# system_slims                                          ['immune system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
#
# [14 rows x 437 columns]

# %%
assembly = assembly_list[0] if len(assembly_list) > 0 else ''
bed_df['assembly'] = assembly
bed_df['biosample_term_id'] = annotation_df.get_value(0, 'biosample_term_id')
bed_df['biosample_term_name'] = annotation_df.get_value(0, 'biosample_term_name')
bed_df['biosample_type'] = annotation_df.get_value(0, 'biosample_type')
bed_df['description'] = annotation_df.get_value(0, 'description')
bed_df['developmental_slims'] = annotation_df.get_value(0, 'developmental_slims')
bed_df['encyclopedia'] = 'ENCODE' 
bed_df['encyclopedia_version'] = annotation_df.get_value(0, 'encyclopedia_version')
bed_df['month_released'] = annotation_df.get_value(0, 'month_released')
bed_df['organ_slims'] = annotation_df.get_value(0, 'organ_slims')
bed_df['organism'] = annotation_df.get_value(0, 'organism')
bed_df['system_slims'] = annotation_df.get_value(0, 'system_slims')

bed_df.T
# Out:
#                                                                   0      \
# chrom                                                              chr1
# start                                                          91852606
# end                                                            91853249
# name                                       Distal-Prediction-Boundary-1
# score                                                                 1
# strand                                                                .
# thickStart                                                     91852820
# thickEnd                                                       91852970
# itemRgb                                                     255,235,200
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
#
#                                                                   1      \
# chrom                                                              chr8
# start                                                          70602170
# end                                                            70602736
# name                                       Distal-Prediction-Boundary-2
# score                                                                 1
# strand                                                                .
# thickStart                                                     70602340
# thickEnd                                                       70602490
# itemRgb                                                     255,235,200
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
#
#                                                                   2      \
# chrom                                                              chr8
# start                                                         100507654
# end                                                           100508251
# name                                       Distal-Prediction-Boundary-3
# score                                                                 1
# strand                                                                .
# thickStart                                                    100508060
# thickEnd                                                      100508210
# itemRgb                                                     255,235,200
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
#
#                                                                   3      \
# chrom                                                             chr11
# start                                                          85194851
# end                                                            85195324
# name                                       Distal-Prediction-Boundary-4
# score                                                                 1
# strand                                                                .
# thickStart                                                     85195040
# thickEnd                                                       85195190
# itemRgb                                                     255,235,200
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
#
#                                                                   4      \
# chrom                                                             chr10
# start                                                          42379744
# end                                                            42380535
# name                                       Distal-Prediction-Boundary-5
# score                                                                 1
# strand                                                                .
# thickStart                                                     42379780
# thickEnd                                                       42379930
# itemRgb                                                     255,235,200
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
#
#                                                                   5      \
# chrom                                                             chr17
# start                                                          33477932
# end                                                            33478557
# name                                       Distal-Prediction-Boundary-6
# score                                                                 1
# strand                                                                .
# thickStart                                                     33478160
# thickEnd                                                       33478310
# itemRgb                                                     255,235,200
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
#
#                                                                   6      \
# chrom                                                              chr1
# start                                                         156186019
# end                                                           156186829
# name                                       Distal-Prediction-Boundary-7
# score                                                                 1
# strand                                                                .
# thickStart                                                    156186420
# thickEnd                                                      156186570
# itemRgb                                                     255,235,200
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
#
#                                                                   7      \
# chrom                                                             chr19
# start                                                          36066304
# end                                                            36066961
# name                                       Distal-Prediction-Boundary-8
# score                                                                 1
# strand                                                                .
# thickStart                                                     36066480
# thickEnd                                                       36066630
# itemRgb                                                     255,235,200
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
#
#                                                                   8      \
# chrom                                                             chr10
# start                                                          42393239
# end                                                            42393622
# name                                       Distal-Prediction-Boundary-9
# score                                                                 1
# strand                                                                .
# thickStart                                                     42393320
# thickEnd                                                       42393470
# itemRgb                                                     255,235,200
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
#
#                                                                   9      \
# chrom                                                              chr4
# start                                                          49151622
# end                                                            49151945
# name                                      Distal-Prediction-Boundary-10
# score                                                                 1
# strand                                                                .
# thickStart                                                     49151700
# thickEnd                                                       49151850
# itemRgb                                                     255,235,200
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
#
#                                             ...                          \
# chrom                                       ...
# start                                       ...
# end                                         ...
# name                                        ...
# score                                       ...
# strand                                      ...
# thickStart                                  ...
# thickEnd                                    ...
# itemRgb                                     ...
# assembly                                    ...
# biosample_term_id                           ...
# biosample_term_name                         ...
# biosample_type                              ...
# description                                 ...
# developmental_slims                         ...
# encyclopedia                                ...
# encyclopedia_version                        ...
# month_released                              ...
# organ_slims                                 ...
# organism                                    ...
# system_slims                                ...
#
#                                                                   71372  \
# chrom                                                              chr2
# start                                                          62376980
# end                                                            62377130
# name                                          Proximal-Prediction-15682
# score                                                                 1
# strand                                                                .
# thickStart                                                     62376980
# thickEnd                                                       62377130
# itemRgb                                                         250,0,0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
#
#                                                                   71373  \
# chrom                                                             chr17
# start                                                          74394140
# end                                                            74394290
# name                                          Proximal-Prediction-15683
# score                                                                 1
# strand                                                                .
# thickStart                                                     74394140
# thickEnd                                                       74394290
# itemRgb                                                         250,0,0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
#
#                                                                   71374  \
# chrom                                                             chr16
# start                                                          30640120
# end                                                            30640270
# name                                          Proximal-Prediction-15684
# score                                                                 1
# strand                                                                .
# thickStart                                                     30640120
# thickEnd                                                       30640270
# itemRgb                                                         250,0,0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
#
#                                                                   71375  \
# chrom                                                             chr19
# start                                                          48201440
# end                                                            48201590
# name                                          Proximal-Prediction-15685
# score                                                                 1
# strand                                                                .
# thickStart                                                     48201440
# thickEnd                                                       48201590
# itemRgb                                                         250,0,0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
#
#                                                                   71376  \
# chrom                                                             chr12
# start                                                          66429220
# end                                                            66429370
# name                                          Proximal-Prediction-15686
# score                                                                 1
# strand                                                                .
# thickStart                                                     66429220
# thickEnd                                                       66429370
# itemRgb                                                         250,0,0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
#
#                                                                   71377  \
# chrom                                                             chr16
# start                                                          27190940
# end                                                            27191090
# name                                          Proximal-Prediction-15687
# score                                                                 1
# strand                                                                .
# thickStart                                                     27190940
# thickEnd                                                       27191090
# itemRgb                                                         250,0,0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
#
#                                                                   71378  \
# chrom                                                              chr1
# start                                                         159147200
# end                                                           159147350
# name                                          Proximal-Prediction-15688
# score                                                                 1
# strand                                                                .
# thickStart                                                    159147200
# thickEnd                                                      159147350
# itemRgb                                                         250,0,0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
#
#                                                                   71379  \
# chrom                                                             chr14
# start                                                          50154920
# end                                                            50155070
# name                                          Proximal-Prediction-15689
# score                                                                 1
# strand                                                                .
# thickStart                                                     50154920
# thickEnd                                                       50155070
# itemRgb                                                         250,0,0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
#
#                                                                   71380  \
# chrom                                                              chr7
# start                                                         100702720
# end                                                           100702870
# name                                          Proximal-Prediction-15690
# score                                                                 1
# strand                                                                .
# thickStart                                                    100702720
# thickEnd                                                      100702870
# itemRgb                                                         250,0,0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
#
#                                                                   71381
# chrom                                                             chr19
# start                                                          10812020
# end                                                            10812170
# name                                          Proximal-Prediction-15691
# score                                                                 1
# strand                                                                .
# thickStart                                                     10812020
# thickEnd                                                       10812170
# itemRgb                                                         250,0,0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
#
# [21 rows x 71382 columns]

# %%
bed_df.to_csv('prova_provola.csv', index=None, sep='\t')

# %%
bed_filepath.split(sep=".")
# Out:
# ['/Users/manuel/development/thesis/download/ENCODE/ENCSR783FDB/files/ENCFF539CZK/ENCFF539CZK',
#  'bed',
#  'gz']

# %%
len(bed_df)
# Out:
# 71382

# %%
bed_df.index.size
# Out:
# 71382

# %%
bed_df['seq_id'] = range(bed_df.index.size)
bed_df['seq_id'] = bed_df['seq_id'].astype(str)

encyclopedia = 'ENCODE'
version = annotation_df.get_value(0, 'encyclopedia_version')
experiment = annotation_df.get_value(0, 'bed_filename').split(sep='.')[0]

bed_df['candidate_id'] = encyclopedia + '.' + str(version) + '.' + experiment + '.' + bed_df['seq_id']

bed_df = bed_df.drop('seq_id', axis=1)
bed_df = bed_df.drop('thickStart', axis=1)
bed_df = bed_df.drop('thickEnd', axis=1)
bed_df = bed_df.drop('itemRgb', axis=1)

bed_df.T
# Out:
#                                                                   0      \
# chrom                                                              chr1
# start                                                          91852606
# end                                                            91853249
# name                                       Distal-Prediction-Boundary-1
# score                                                                 1
# strand                                                                .
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# candidate_id                                     ENCODE.3.ENCFF539CZK.0
#
#                                                                   1      \
# chrom                                                              chr8
# start                                                          70602170
# end                                                            70602736
# name                                       Distal-Prediction-Boundary-2
# score                                                                 1
# strand                                                                .
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# candidate_id                                     ENCODE.3.ENCFF539CZK.1
#
#                                                                   2      \
# chrom                                                              chr8
# start                                                         100507654
# end                                                           100508251
# name                                       Distal-Prediction-Boundary-3
# score                                                                 1
# strand                                                                .
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# candidate_id                                     ENCODE.3.ENCFF539CZK.2
#
#                                                                   3      \
# chrom                                                             chr11
# start                                                          85194851
# end                                                            85195324
# name                                       Distal-Prediction-Boundary-4
# score                                                                 1
# strand                                                                .
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# candidate_id                                     ENCODE.3.ENCFF539CZK.3
#
#                                                                   4      \
# chrom                                                             chr10
# start                                                          42379744
# end                                                            42380535
# name                                       Distal-Prediction-Boundary-5
# score                                                                 1
# strand                                                                .
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# candidate_id                                     ENCODE.3.ENCFF539CZK.4
#
#                                                                   5      \
# chrom                                                             chr17
# start                                                          33477932
# end                                                            33478557
# name                                       Distal-Prediction-Boundary-6
# score                                                                 1
# strand                                                                .
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# candidate_id                                     ENCODE.3.ENCFF539CZK.5
#
#                                                                   6      \
# chrom                                                              chr1
# start                                                         156186019
# end                                                           156186829
# name                                       Distal-Prediction-Boundary-7
# score                                                                 1
# strand                                                                .
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# candidate_id                                     ENCODE.3.ENCFF539CZK.6
#
#                                                                   7      \
# chrom                                                             chr19
# start                                                          36066304
# end                                                            36066961
# name                                       Distal-Prediction-Boundary-8
# score                                                                 1
# strand                                                                .
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# candidate_id                                     ENCODE.3.ENCFF539CZK.7
#
#                                                                   8      \
# chrom                                                             chr10
# start                                                          42393239
# end                                                            42393622
# name                                       Distal-Prediction-Boundary-9
# score                                                                 1
# strand                                                                .
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# candidate_id                                     ENCODE.3.ENCFF539CZK.8
#
#                                                                   9      \
# chrom                                                              chr4
# start                                                          49151622
# end                                                            49151945
# name                                      Distal-Prediction-Boundary-10
# score                                                                 1
# strand                                                                .
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# candidate_id                                     ENCODE.3.ENCFF539CZK.9
#
#                                             ...                          \
# chrom                                       ...
# start                                       ...
# end                                         ...
# name                                        ...
# score                                       ...
# strand                                      ...
# assembly                                    ...
# biosample_term_id                           ...
# biosample_term_name                         ...
# biosample_type                              ...
# description                                 ...
# developmental_slims                         ...
# encyclopedia                                ...
# encyclopedia_version                        ...
# month_released                              ...
# organ_slims                                 ...
# organism                                    ...
# system_slims                                ...
# candidate_id                                ...
#
#                                                                   71372  \
# chrom                                                              chr2
# start                                                          62376980
# end                                                            62377130
# name                                          Proximal-Prediction-15682
# score                                                                 1
# strand                                                                .
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# candidate_id                                 ENCODE.3.ENCFF539CZK.71372
#
#                                                                   71373  \
# chrom                                                             chr17
# start                                                          74394140
# end                                                            74394290
# name                                          Proximal-Prediction-15683
# score                                                                 1
# strand                                                                .
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# candidate_id                                 ENCODE.3.ENCFF539CZK.71373
#
#                                                                   71374  \
# chrom                                                             chr16
# start                                                          30640120
# end                                                            30640270
# name                                          Proximal-Prediction-15684
# score                                                                 1
# strand                                                                .
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# candidate_id                                 ENCODE.3.ENCFF539CZK.71374
#
#                                                                   71375  \
# chrom                                                             chr19
# start                                                          48201440
# end                                                            48201590
# name                                          Proximal-Prediction-15685
# score                                                                 1
# strand                                                                .
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# candidate_id                                 ENCODE.3.ENCFF539CZK.71375
#
#                                                                   71376  \
# chrom                                                             chr12
# start                                                          66429220
# end                                                            66429370
# name                                          Proximal-Prediction-15686
# score                                                                 1
# strand                                                                .
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# candidate_id                                 ENCODE.3.ENCFF539CZK.71376
#
#                                                                   71377  \
# chrom                                                             chr16
# start                                                          27190940
# end                                                            27191090
# name                                          Proximal-Prediction-15687
# score                                                                 1
# strand                                                                .
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# candidate_id                                 ENCODE.3.ENCFF539CZK.71377
#
#                                                                   71378  \
# chrom                                                              chr1
# start                                                         159147200
# end                                                           159147350
# name                                          Proximal-Prediction-15688
# score                                                                 1
# strand                                                                .
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# candidate_id                                 ENCODE.3.ENCFF539CZK.71378
#
#                                                                   71379  \
# chrom                                                             chr14
# start                                                          50154920
# end                                                            50155070
# name                                          Proximal-Prediction-15689
# score                                                                 1
# strand                                                                .
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# candidate_id                                 ENCODE.3.ENCFF539CZK.71379
#
#                                                                   71380  \
# chrom                                                              chr7
# start                                                         100702720
# end                                                           100702870
# name                                          Proximal-Prediction-15690
# score                                                                 1
# strand                                                                .
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# candidate_id                                 ENCODE.3.ENCFF539CZK.71380
#
#                                                                   71381
# chrom                                                             chr19
# start                                                          10812020
# end                                                            10812170
# name                                          Proximal-Prediction-15691
# score                                                                 1
# strand                                                                .
# assembly                                                           hg19
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# candidate_id                                 ENCODE.3.ENCFF539CZK.71381
#
# [19 rows x 71382 columns]

# %%
desc = bed_df.get_value(0, 'description')

# %%
len(annotation_df[annotation_df['description'].str.contains('DNase-only')])
# Out:
# 192

# %%
len(annotation_df[annotation_df['description'].str.contains('H3K27ac-only')])
# Out:
# 184

# %%
len(annotation_df[annotation_df['description'].str.contains('DNase and H3K27ac')])
# Out:
# 61

# %%
annotation_df.head()
# Out:
#          accession          assembly biosample_term_id  \
# index
# 0      ENCSR783FDB          ['hg19']        CL:0002618
# 1      ENCSR312DDF  ['mm10-minimal']    UBERON:0000948
# 2      ENCSR960QES  ['mm10-minimal']    UBERON:0001891
# 3      ENCSR615QPD  ['mm10-minimal']    UBERON:0002107
# 4      ENCSR522DOY          ['hg19']        CL:0002586
#
#                       biosample_term_name biosample_type  \
# index
# 0      endothelial cell of umbilical vein   primary cell
# 1                                   heart         tissue
# 2                                midbrain         tissue
# 3                                   liver         tissue
# 4         retinal pigment epithelial cell   primary cell
#
#                                              description developmental_slims  \
# index
# 0      Enhancer-like regions using DNase-only for end...        ['mesoderm']
# 1      Enhancer-like regions using H3K27ac-only for h...        ['mesoderm']
# 2      Enhancer-like regions using DNase and H3K27ac ...        ['ectoderm']
# 3      Enhancer-like regions using H3K27ac-only for l...        ['endoderm']
# 4      Enhancer-like regions using DNase-only for ret...        ['ectoderm']
#
#        encyclopedia_version month_released       organ_slims  \
# index
# 0                         3     June, 2016  ['blood vessel']
# 1                         3   August, 2016         ['heart']
# 2                         3   August, 2016         ['brain']
# 3                         3   August, 2016         ['liver']
# 4                         3     June, 2016           ['eye']
#
#                 organism                              system_slims  \
# index
# 0      /organisms/human/                    ['circulatory system']
# 1                    NaN                    ['circulatory system']
# 2                    NaN                ['central nervous system']
# 3                    NaN  ['endocrine system', 'digestive system']
# 4      /organisms/human/                        ['sensory system']
#
#              bed_filename                                       bed_filepath  \
# index
# 0      ENCFF539CZK.bed.gz  /Users/manuel/development/thesis/download/ENCO...
# 1      ENCFF539CZK.bed.gz  /Users/manuel/development/thesis/download/ENCO...
# 2      ENCFF539CZK.bed.gz  /Users/manuel/development/thesis/download/ENCO...
# 3      ENCFF539CZK.bed.gz  /Users/manuel/development/thesis/download/ENCO...
# 4      ENCFF539CZK.bed.gz  /Users/manuel/development/thesis/download/ENCO...
#
#                                        method
# index
# 0      <function label_method at 0x1264066a8>
# 1      <function label_method at 0x1264066a8>
# 2      <function label_method at 0x1264066a8>
# 3      <function label_method at 0x1264066a8>
# 4      <function label_method at 0x1264066a8>

# %%
def label_method(row):
    description = row['description']
    if 'DNase-only' in description:
        return 'DNase'
    if 'H3K27ac-only' in description:
        return 'H3K27ac'
    if 'DNase and H3K27ac' in description:
        return 'DNase+H3K27ac'
    else:
        return 'Unknown'
    
def print_desc(row):
    desc = str(row['description'])
    if 'DNase-only' in desc:
        print("OK")

# %%
annotation_df['method'] = annotation_df.apply(lambda row: label_method(row), axis=1)

# %%
annotation_df.T
# Out:
# index                                                               0    \
# accession                                                   ENCSR783FDB
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                            DNase
#
# index                                                               1    \
# accession                                                   ENCSR312DDF
# assembly                                               ['mm10-minimal']
# biosample_term_id                                        UBERON:0000948
# biosample_term_name                                               heart
# biosample_type                                                   tissue
# description           Enhancer-like regions using H3K27ac-only for h...
# developmental_slims                                        ['mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                   ['heart']
# organism                                                            NaN
# system_slims                                     ['circulatory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
#
# index                                                               2    \
# accession                                                   ENCSR960QES
# assembly                                               ['mm10-minimal']
# biosample_term_id                                        UBERON:0001891
# biosample_term_name                                            midbrain
# biosample_type                                                   tissue
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                   ['brain']
# organism                                                            NaN
# system_slims                                 ['central nervous system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                    DNase+H3K27ac
#
# index                                                               3    \
# accession                                                   ENCSR615QPD
# assembly                                               ['mm10-minimal']
# biosample_term_id                                        UBERON:0002107
# biosample_term_name                                               liver
# biosample_type                                                   tissue
# description           Enhancer-like regions using H3K27ac-only for l...
# developmental_slims                                        ['endoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                   ['liver']
# organism                                                            NaN
# system_slims                   ['endocrine system', 'digestive system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
#
# index                                                               4    \
# accession                                                   ENCSR522DOY
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002586
# biosample_term_name                     retinal pigment epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for ret...
# developmental_slims                                        ['ectoderm']
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                     ['eye']
# organism                                              /organisms/human/
# system_slims                                         ['sensory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                            DNase
#
# index                                                               5    \
# accession                                                   ENCSR765XEI
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002518
# biosample_term_name                              kidney epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for kid...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                  ['kidney']
# organism                                              /organisms/human/
# system_slims                                       ['excretory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                            DNase
#
# index                                                               6    \
# accession                                                   ENCSR385UEZ
# assembly                                                       ['hg19']
# biosample_term_id                                           NTR:0000711
# biosample_term_name                              neural progenitor cell
# biosample_type                            in vitro differentiated cells
# description           Enhancer-like regions using DNase-only for neu...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                          []
# organism                                              /organisms/human/
# system_slims                                                         []
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                            DNase
#
# index                                                               7    \
# accession                                                   ENCSR891WXH
# assembly                                                       ['hg19']
# biosample_term_id                                           EFO:0002796
# biosample_term_name                                              Jurkat
# biosample_type                                   immortalized cell line
# description           Enhancer-like regions using DNase-only for Jurkat
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                          []
# organism                                              /organisms/human/
# system_slims                                                         []
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                            DNase
#
# index                                                               8    \
# accession                                                   ENCSR359JDI
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002188
# biosample_term_name                         glomerular endothelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for glo...
# developmental_slims                                        ['mesoderm']
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                  ['kidney']
# organism                                              /organisms/human/
# system_slims                                       ['excretory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                            DNase
#
# index                                                               9    \
# accession                                                   ENCSR918NER
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002552
# biosample_term_name                               fibroblast of gingiva
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for fib...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                   ['mouth']
# organism                                              /organisms/human/
# system_slims                                       ['digestive system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                            DNase
#
# index                                       ...                          \
# accession                                   ...
# assembly                                    ...
# biosample_term_id                           ...
# biosample_term_name                         ...
# biosample_type                              ...
# description                                 ...
# developmental_slims                         ...
# encyclopedia_version                        ...
# month_released                              ...
# organ_slims                                 ...
# organism                                    ...
# system_slims                                ...
# bed_filename                                ...
# bed_filepath                                ...
# method                                      ...
#
# index                                                               427  \
# accession                                                   ENCSR643FZD
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0000492
# biosample_term_name                          CD4-positive helper T cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for P...
# developmental_slims                            ['endoderm', 'mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                          []
# organism                                                            NaN
# system_slims                                          ['immune system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
#
# index                                                               428  \
# accession                                                   ENCSR516DXQ
# assembly                                                       ['hg19']
# biosample_term_id                                        UBERON:0000945
# biosample_term_name                                             stomach
# biosample_type                                                   tissue
# description           Enhancer-like regions using H3K27ac-only for G...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                 ['stomach']
# organism                                                            NaN
# system_slims                                       ['digestive system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
#
# index                                                               429  \
# accession                                                   ENCSR807AHZ
# assembly                                                       ['hg19']
# biosample_term_id                                        UBERON:0001043
# biosample_term_name                                           esophagus
# biosample_type                                                   tissue
# description           Enhancer-like regions using H3K27ac-only for E...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                               ['esophagus']
# organism                                                            NaN
# system_slims                                       ['digestive system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
#
# index                                                               430  \
# accession                                                   ENCSR977MRM
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0000236
# biosample_term_name                                              B cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                          []
# organism                                              /organisms/human/
# system_slims                                          ['immune system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                    DNase+H3K27ac
#
# index                                                               431  \
# accession                                                   ENCSR374MQO
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for U...
# developmental_slims                                        ['mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                            ['blood vessel']
# organism                                                            NaN
# system_slims                                     ['circulatory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
#
# index                                                               432  \
# accession                                                   ENCSR750HZU
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0000492
# biosample_term_name                          CD4-positive helper T cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for P...
# developmental_slims                            ['endoderm', 'mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                          []
# organism                                                            NaN
# system_slims                                          ['immune system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
#
# index                                                               433  \
# accession                                                   ENCSR226GOY
# assembly                                                       ['hg19']
# biosample_term_id                                        UBERON:0002369
# biosample_term_name                                       adrenal gland
# biosample_type                                                   tissue
# description           Enhancer-like regions using H3K27ac-only for F...
# developmental_slims                            ['ectoderm', 'mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                           ['adrenal gland']
# organism                                                            NaN
# system_slims                                       ['endocrine system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
#
# index                                                               434  \
# accession                                                   ENCSR936YWW
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for M...
# developmental_slims                                        ['ectoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                           ['mammary gland']
# organism                                                            NaN
# system_slims                                    ['integumental system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
#
# index                                                               435  \
# accession                                                   ENCSR122FDL
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0000492
# biosample_term_name                          CD4-positive helper T cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for P...
# developmental_slims                            ['endoderm', 'mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                          []
# organism                                                            NaN
# system_slims                                          ['immune system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
#
# index                                                               436
# accession                                                   ENCSR277LBT
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0000084
# biosample_term_name                                              T-cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for P...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                          []
# organism                                                            NaN
# system_slims                                          ['immune system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
#
# [15 rows x 437 columns]

# %%
annotation_df.insert(annotation_df.columns.size, 'asd', 'a')

# %%
annotation_df.T
# Out:
# index                                                               0    \
# strombolo                                                             a
# accession                                                   ENCSR783FDB
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for end...
# developmental_slims                                        ['mesoderm']
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['blood vessel']
# organism                                              /organisms/human/
# system_slims                                     ['circulatory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                            DNase
# cane
# c                                                                     a
# asd                                                                   a
#
# index                                                               1    \
# strombolo                                                             a
# accession                                                   ENCSR312DDF
# assembly                                               ['mm10-minimal']
# biosample_term_id                                        UBERON:0000948
# biosample_term_name                                               heart
# biosample_type                                                   tissue
# description           Enhancer-like regions using H3K27ac-only for h...
# developmental_slims                                        ['mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                   ['heart']
# organism                                                            NaN
# system_slims                                     ['circulatory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
# cane
# c                                                                     a
# asd                                                                   a
#
# index                                                               2    \
# strombolo                                                             a
# accession                                                   ENCSR960QES
# assembly                                               ['mm10-minimal']
# biosample_term_id                                        UBERON:0001891
# biosample_term_name                                            midbrain
# biosample_type                                                   tissue
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                   ['brain']
# organism                                                            NaN
# system_slims                                 ['central nervous system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                    DNase+H3K27ac
# cane
# c                                                                     a
# asd                                                                   a
#
# index                                                               3    \
# strombolo                                                             a
# accession                                                   ENCSR615QPD
# assembly                                               ['mm10-minimal']
# biosample_term_id                                        UBERON:0002107
# biosample_term_name                                               liver
# biosample_type                                                   tissue
# description           Enhancer-like regions using H3K27ac-only for l...
# developmental_slims                                        ['endoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                   ['liver']
# organism                                                            NaN
# system_slims                   ['endocrine system', 'digestive system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
# cane
# c                                                                     a
# asd                                                                   a
#
# index                                                               4    \
# strombolo                                                             a
# accession                                                   ENCSR522DOY
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002586
# biosample_term_name                     retinal pigment epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for ret...
# developmental_slims                                        ['ectoderm']
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                     ['eye']
# organism                                              /organisms/human/
# system_slims                                         ['sensory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                            DNase
# cane
# c                                                                     a
# asd                                                                   a
#
# index                                                               5    \
# strombolo                                                             a
# accession                                                   ENCSR765XEI
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002518
# biosample_term_name                              kidney epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for kid...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                  ['kidney']
# organism                                              /organisms/human/
# system_slims                                       ['excretory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                            DNase
# cane
# c                                                                     a
# asd                                                                   a
#
# index                                                               6    \
# strombolo                                                             a
# accession                                                   ENCSR385UEZ
# assembly                                                       ['hg19']
# biosample_term_id                                           NTR:0000711
# biosample_term_name                              neural progenitor cell
# biosample_type                            in vitro differentiated cells
# description           Enhancer-like regions using DNase-only for neu...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                          []
# organism                                              /organisms/human/
# system_slims                                                         []
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                            DNase
# cane
# c                                                                     a
# asd                                                                   a
#
# index                                                               7    \
# strombolo                                                             a
# accession                                                   ENCSR891WXH
# assembly                                                       ['hg19']
# biosample_term_id                                           EFO:0002796
# biosample_term_name                                              Jurkat
# biosample_type                                   immortalized cell line
# description           Enhancer-like regions using DNase-only for Jurkat
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                          []
# organism                                              /organisms/human/
# system_slims                                                         []
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                            DNase
# cane
# c                                                                     a
# asd                                                                   a
#
# index                                                               8    \
# strombolo                                                             a
# accession                                                   ENCSR359JDI
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002188
# biosample_term_name                         glomerular endothelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for glo...
# developmental_slims                                        ['mesoderm']
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                  ['kidney']
# organism                                              /organisms/human/
# system_slims                                       ['excretory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                            DNase
# cane
# c                                                                     a
# asd                                                                   a
#
# index                                                               9    \
# strombolo                                                             a
# accession                                                   ENCSR918NER
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002552
# biosample_term_name                               fibroblast of gingiva
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase-only for fib...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                   ['mouth']
# organism                                              /organisms/human/
# system_slims                                       ['digestive system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                            DNase
# cane
# c                                                                     a
# asd                                                                   a
#
# index                                       ...                          \
# strombolo                                   ...
# accession                                   ...
# assembly                                    ...
# biosample_term_id                           ...
# biosample_term_name                         ...
# biosample_type                              ...
# description                                 ...
# developmental_slims                         ...
# encyclopedia_version                        ...
# month_released                              ...
# organ_slims                                 ...
# organism                                    ...
# system_slims                                ...
# bed_filename                                ...
# bed_filepath                                ...
# method                                      ...
# cane                                        ...
# c                                           ...
# asd                                         ...
#
# index                                                               427  \
# strombolo                                                             a
# accession                                                   ENCSR643FZD
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0000492
# biosample_term_name                          CD4-positive helper T cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for P...
# developmental_slims                            ['endoderm', 'mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                          []
# organism                                                            NaN
# system_slims                                          ['immune system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
# cane
# c                                                                     a
# asd                                                                   a
#
# index                                                               428  \
# strombolo                                                             a
# accession                                                   ENCSR516DXQ
# assembly                                                       ['hg19']
# biosample_term_id                                        UBERON:0000945
# biosample_term_name                                             stomach
# biosample_type                                                   tissue
# description           Enhancer-like regions using H3K27ac-only for G...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                 ['stomach']
# organism                                                            NaN
# system_slims                                       ['digestive system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
# cane
# c                                                                     a
# asd                                                                   a
#
# index                                                               429  \
# strombolo                                                             a
# accession                                                   ENCSR807AHZ
# assembly                                                       ['hg19']
# biosample_term_id                                        UBERON:0001043
# biosample_term_name                                           esophagus
# biosample_type                                                   tissue
# description           Enhancer-like regions using H3K27ac-only for E...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                               ['esophagus']
# organism                                                            NaN
# system_slims                                       ['digestive system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
# cane
# c                                                                     a
# asd                                                                   a
#
# index                                                               430  \
# strombolo                                                             a
# accession                                                   ENCSR977MRM
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0000236
# biosample_term_name                                              B cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                                          []
# organism                                              /organisms/human/
# system_slims                                          ['immune system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                    DNase+H3K27ac
# cane
# c                                                                     a
# asd                                                                   a
#
# index                                                               431  \
# strombolo                                                             a
# accession                                                   ENCSR374MQO
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002618
# biosample_term_name                  endothelial cell of umbilical vein
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for U...
# developmental_slims                                        ['mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                            ['blood vessel']
# organism                                                            NaN
# system_slims                                     ['circulatory system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
# cane
# c                                                                     a
# asd                                                                   a
#
# index                                                               432  \
# strombolo                                                             a
# accession                                                   ENCSR750HZU
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0000492
# biosample_term_name                          CD4-positive helper T cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for P...
# developmental_slims                            ['endoderm', 'mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                          []
# organism                                                            NaN
# system_slims                                          ['immune system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
# cane
# c                                                                     a
# asd                                                                   a
#
# index                                                               433  \
# strombolo                                                             a
# accession                                                   ENCSR226GOY
# assembly                                                       ['hg19']
# biosample_term_id                                        UBERON:0002369
# biosample_term_name                                       adrenal gland
# biosample_type                                                   tissue
# description           Enhancer-like regions using H3K27ac-only for F...
# developmental_slims                            ['ectoderm', 'mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                           ['adrenal gland']
# organism                                                            NaN
# system_slims                                       ['endocrine system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
# cane
# c                                                                     a
# asd                                                                   a
#
# index                                                               434  \
# strombolo                                                             a
# accession                                                   ENCSR936YWW
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for M...
# developmental_slims                                        ['ectoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                           ['mammary gland']
# organism                                                            NaN
# system_slims                                    ['integumental system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
# cane
# c                                                                     a
# asd                                                                   a
#
# index                                                               435  \
# strombolo                                                             a
# accession                                                   ENCSR122FDL
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0000492
# biosample_term_name                          CD4-positive helper T cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for P...
# developmental_slims                            ['endoderm', 'mesoderm']
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                          []
# organism                                                            NaN
# system_slims                                          ['immune system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
# cane
# c                                                                     a
# asd                                                                   a
#
# index                                                               436
# strombolo                                                             a
# accession                                                   ENCSR277LBT
# assembly                                                       ['hg19']
# biosample_term_id                                            CL:0000084
# biosample_term_name                                              T-cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using H3K27ac-only for P...
# developmental_slims                                                  []
# encyclopedia_version                                                  3
# month_released                                             August, 2016
# organ_slims                                                          []
# organism                                                            NaN
# system_slims                                          ['immune system']
# bed_filename                                         ENCFF539CZK.bed.gz
# bed_filepath          /Users/manuel/development/thesis/download/ENCO...
# method                                                          H3K27ac
# cane
# c                                                                     a
# asd                                                                   a
#
# [19 rows x 437 columns]

# %%
import time
print (time.strftime("%Y%m%d"))
# Out:
# 20170106

# %% [markdown]
# ## dbSUPER overlaps

# %% [markdown]
# ### Overlaps using dbSUPER upload tool

# %%
# load sample and overlap files generated by dbSUPER overlap tool
dbSUPER_filepath = '/Users/manuel/development/thesis/staging/dbSUPER/'
sample_bed_filepath = dbSUPER_filepath + 'adrenal_gland_ENCODE_sample.bed'
sample_bed = BedTool(sample_bed_filepath)

sample_ovlpby_dbSUPER_bed_filepath = dbSUPER_filepath + 'overlapped/adrenal_gland_overlapped_by_dbSUPER.bed'
sample_ovlpby_dbSUPER_bed = BedTool(sample_ovlpby_dbSUPER_bed_filepath)

dbSUPER_ovlpby_sample_bed_filepath = dbSUPER_filepath + 'overlapped/dbSuper_overlapped_by_adrenal_gland.bed'
dbSUPER_ovlpby_sample_bed = BedTool(dbSUPER_ovlpby_sample_bed_filepath)

# %%
sample_df = sample_bed.to_dataframe()

# %%
print(len(super_ovlp_sample_df), "overlaps found")
super_ovlp_sample_df = sample_ovlpby_dbSUPER_bed.to_dataframe()
# Out:
# 802 overlaps found

# %%
sample_ovlp_super_df = dbSUPER_ovlpby_sample_bed.to_dataframe()
sample_ovlp_super_df.columns = \
['chrom', 'start', 'end', 'SE_name', 'chromm', 'startt', 'endd', 'name', 'score', 'strand', \
 'thickStart', 'thickEnd', 'itemRgb']
# Out:
# /Users/manuel/anaconda/lib/python3.5/site-packages/pybedtools/bedtool.py:3199: UserWarning: Default names for filetype bed are:
# ['chrom', 'start', 'end', 'name', 'score', 'strand', 'thickStart', 'thickEnd', 'itemRgb', 'blockCount', 'blockSizes', 'blockStarts']
# but file has 13 fields; you can supply custom names with the `names` kwarg
#   % (self.file_type, _names, self.field_count()))

# %%
print(len(sample_ovlp_super_df), "overlaps found")
sample_ovlp_super_df.head()
# Out:
# 802 overlaps found
#   chrom      start        end   SE_name chromm     startt       endd  \
# 0  chr1   21586078   21599802  SE_00854   chr1   21586078   21599802
# 1  chr1   21638270   21671678  SE_00854   chr1   21638270   21671678
# 2  chr5  172293155  172304022  SE_00858   chr5  172293155  172304022
# 3  chr1   27902477   27930697  SE_00861   chr1   27902477   27930697
# 4  chr6   31972198   31975413  SE_00862   chr6   31972198   31975413
#
#                        name  score strand  thickStart   thickEnd    itemRgb
# 0   Proximal-Prediction-610      1      .    21589400   21589550    255,0,0
# 1  Proximal-Prediction-1753      1      .    21643920   21644070    255,0,0
# 2     Distal-Prediction-448      1      .   172299100  172299250  255,205,0
# 3  Proximal-Prediction-3598      1      .    27925780   27925930    255,0,0
# 4  Proximal-Prediction-9487      1      .    31973240   31973390    255,0,0

# %%
# choose a putative enhancer from the ENCODE sample and query it
queryname = 'Distal-Prediction-448'

query_sample = sample_df.query('name == @queryname')
query_sample_ovlp_super = sample_ovlp_super_df.query('name == @queryname')

# %%
query_sample
# Out:
#     chrom      start        end                   name  score strand  \
# 447  chr5  172293155  172304022  Distal-Prediction-448      1      .
#
#      thickStart   thickEnd    itemRgb
# 447   172299100  172299250  255,205,0

# %%
query_sample_ovlp_super.head()
# Out:
#   chrom      start        end   SE_name chromm     startt       endd  \
# 2  chr5  172293155  172304022  SE_00858   chr5  172293155  172304022
#
#                     name  score strand  thickStart   thickEnd    itemRgb
# 2  Distal-Prediction-448      1      .   172299100  172299250  255,205,0

# %%
# Found overlapping super enhancers
SE_names_query = list(query_sample_ovlp_super['SE_name'])
print(queryname, "overlaps", len(SE_names_query), "super-enhancers")
# Out:
# Distal-Prediction-448 overlaps 1 super-enhancers

# %%
query_super_ovlp_sample = super_ovlp_sample_df.query('name in @SE_names_query')

# %%
query_super_ovlp_sample
# Out:
#   chrom      start        end      name
# 2  chr5  172259359  172367617  SE_00858

# %%
# load overlap details (it can be substituted by the full dbSUPER in csv format if possible)
overlap_details = '/Users/manuel/development/thesis/staging/dbSUPER/overlapped/dbSUPER_adrenal_gland_Overlap_Analysis.csv'
overlap_dbSUPER_details_df = pd.read_csv(overlap_details)
overlap_dbSUPER_details_df.head()
# Out:
#          ID Chrom      Start       Stop Associated Gene   Method  Rank  \
# 0  SE_00854  chr1   21563495   21672486            ECE1  H3K27ac     2
# 1  SE_00854  chr1   21563495   21672486            ECE1  H3K27ac     2
# 2  SE_00861  chr1   27845422   27931151           AHDC1  H3K27ac     9
# 3  SE_00902  chr1  156425935  156479933           MEF2D  H3K27ac    50
# 4  SE_00908  chr1   22220354   22266635           HSPG2  H3K27ac    56
#
#      Cell/Tissue Genome
# 0  Adrenal Gland   hg19
# 1  Adrenal Gland   hg19
# 2  Adrenal Gland   hg19
# 3  Adrenal Gland   hg19
# 4  Adrenal Gland   hg19

# %%
# find details for the overlapped super-enhancers
query_dbSUPER_details = overlap_dbSUPER_details_df.query('ID in @SE_names_query')
query_dbSUPER_details
# Out:
#            ID Chrom      Start       Stop Associated Gene   Method  Rank  \
# 650  SE_00858  chr5  172259359  172367617          ERGIC1  H3K27ac     6
#
#        Cell/Tissue Genome
# 650  Adrenal Gland   hg19

# %% [markdown]
# ### Overlaps using pybedtools

# %%
# find overlaps using pybedtools
adrenal_gland_dbSUPER_bed_filepath = dbSUPER_filepath + 'adrenal_gland_dbSUPER_sample.bed'
adrenal_gland_dbSUPER_bed = BedTool(adrenal_gland_dbSUPER_bed_filepath)

adrenal_gland_ENCODE_bed_filepath = dbSUPER_filepath + 'adrenal_gland_ENCODE_sample.bed'
adrenal_gland_ENCODE_bed = BedTool(adrenal_gland_ENCODE_bed_filepath)

# %%
# wa = mantains the original A feature for A.intersect(B), u = unique, 
# loj = Left outer join: report features in A with and without overlaps
# f = by default, bedtools intersect will report an overlap between A and B 
# so long as there is at least one base pair is overlapping. 
# To restrict reported overlaps between A and B to cases where the feature in B overlaps at least X% (e.g. 50%) 
# of the A feature

#the exact list obtained from the upload tool is obtainable with:
#ag_dbSUPER_intersect_ENCODE = adrenal_gland_dbSUPER_bed.intersect(adrenal_gland_ENCODE_bed, wa=True, f=0.1)

ag_dbSUPER_intersect_ENCODE = adrenal_gland_dbSUPER_bed.intersect(adrenal_gland_ENCODE_bed, wa=True, f=0.1)
ag_ENCODE_intersect_dbSUPER = adrenal_gland_ENCODE_bed.intersect(adrenal_gland_dbSUPER_bed, loj=True, f=0.1)

print(len(ag_dbSUPER_intersect_ENCODE), "dbSUPER.intersect(ENCODE) results")
print(len(ag_ENCODE_intersect_dbSUPER), "ENCODE.intersect(dbSUPER) results")
# Out:
# 802 dbSUPER.intersect(ENCODE) results
# 38634 ENCODE.intersect(dbSUPER) results

# %%
ag_dbSUPER_intersect_ENCODE.to_dataframe().T
# Out:
#              0          1         2         3         4         5          6   \
# chrom     chr11      chr11     chr15     chr19     chr20      chr7      chr12
# start  65237743  118777683  96863927   1247386  43964010   5457535  122229391
# end    65278340  118801134  96903646   1256258  43989148   5470356  122240211
# name   SE_00879   SE_00888  SE_00940  SE_00962  SE_00964  SE_00981   SE_01014
# score        27         36        88       110       112       129        162
#
#              7         8         9     ...            89         90        91  \
# chrom      chr6      chr7     chr19    ...         chr22       chr7      chr1
# start  35685764   1570046  42745986    ...      37589854  150942922  46766256
# end    35701350   1578500  42760924    ...      37595511  150950017  46770097
# name   SE_01032  SE_01055  SE_01058    ...      SE_01465   SE_01475  SE_01482
# score       180       203       206    ...           613        623       630
#
#              92        93        94        95         96         97         98
# chrom     chr12     chr13     chr17     chr16       chr4       chr3       chr8
# start   6975456  80911142   3788828  29815865  185393397  139250833  103663429
# end     6983422  80917590   3800155  29821734  185396895  139259205  103670785
# name   SE_01489  SE_01501  SE_01510  SE_01513   SE_01521   SE_01524   SE_01525
# score       637       649       658       661        669        672        673
#
# [5 rows x 99 columns]

# %%
ag_overlap_df = ag_ENCODE_intersect_dbSUPER.to_dataframe()
ag_overlap_df.columns = \
['chrom', 'start', 'end', 'name', 'score', 'strand', 'thickStart', 'thickEnd', 'itemRgb', 'SE_chrom', \
 'SE_start', 'SE_end', 'SE_name', 'SE_score']
ag_overlap_df.T
# Out:
# /Users/manuel/anaconda/lib/python3.5/site-packages/pybedtools/bedtool.py:3199: UserWarning: Default names for filetype bed are:
# ['chrom', 'start', 'end', 'name', 'score', 'strand', 'thickStart', 'thickEnd', 'itemRgb', 'blockCount', 'blockSizes', 'blockStarts']
# but file has 14 fields; you can supply custom names with the `names` kwarg
#   % (self.file_type, _names, self.field_count()))
#                           0                    1                    2      \
# chrom                     chr13                chr14                chr16
# start                  34114318             35800256             22200146
# end                    34118911             35812312             22205387
# name        Distal-Prediction-1  Distal-Prediction-2  Distal-Prediction-3
# score                         1                    1                    1
# strand                        .                    .                    .
# thickStart             34116600             35805960             22202200
# thickEnd               34116750             35806110             22202350
# itemRgb               255,205,0            255,205,0            255,205,0
# SE_chrom                      .                chr14                    .
# SE_start                     -1             35800648                   -1
# SE_end                       -1             35813368                   -1
# SE_name                       .             SE_01165                    .
# SE_score                     -1                  313                   -1
#
#                           3                    4                    5      \
# chrom                     chr14                chr12                chr19
# start                  62025090              8178209             18413303
# end                    62033524              8180468             18418380
# name        Distal-Prediction-4  Distal-Prediction-5  Distal-Prediction-6
# score                         1                    1                    1
# strand                        .                    .                    .
# thickStart             62029640              8179240             18415380
# thickEnd               62029790              8179390             18415530
# itemRgb               255,205,0            255,205,0            255,205,0
# SE_chrom                  chr14                    .                    .
# SE_start               61977862                   -1                   -1
# SE_end                 62062455                   -1                   -1
# SE_name                SE_00951                    .                    .
# SE_score                     99                   -1                   -1
#
#                           6                    7                    8      \
# chrom                     chr17                chr19                 chr7
# start                  41436643              2057975            130008428
# end                    41439942              2063141            130015073
# name        Distal-Prediction-7  Distal-Prediction-8  Distal-Prediction-9
# score                         1                    1                    1
# strand                        .                    .                    .
# thickStart             41438460              2061560            130013740
# thickEnd               41438610              2061710            130013890
# itemRgb               255,205,0            255,205,0            255,205,0
# SE_chrom                      .                chr19                    .
# SE_start                     -1              2031672                   -1
# SE_end                       -1              2094175                   -1
# SE_name                       .             SE_00877                    .
# SE_score                     -1                   25                   -1
#
#                            9                ...              \
# chrom                      chr19            ...
# start                   39891316            ...
# end                     39895380            ...
# name        Distal-Prediction-10            ...
# score                          1            ...
# strand                         .            ...
# thickStart              39894500            ...
# thickEnd                39894650            ...
# itemRgb                255,205,0            ...
# SE_chrom                   chr19            ...
# SE_start                39887759            ...
# SE_end                  39902523            ...
# SE_name                 SE_01016            ...
# SE_score                     164            ...
#
#                                 38624                      38625  \
# chrom                           chr19                      chr19
# start                        46880463                   45260914
# end                          46882005                   45261457
# name        Proximal-Prediction-18625  Proximal-Prediction-18626
# score                               1                          1
# strand                              .                          .
# thickStart                   46881600                   45261200
# thickEnd                     46881750                   45261350
# itemRgb                       255,0,0                    255,0,0
# SE_chrom                            .                      chr19
# SE_start                           -1                   45240079
# SE_end                             -1                   45263101
# SE_name                             .                   SE_01042
# SE_score                           -1                        190
#
#                                 38626                      38627  \
# chrom                           chr17                      chr19
# start                        52847987                   11465980
# end                          52848805                   11466130
# name        Proximal-Prediction-18627  Proximal-Prediction-18628
# score                               1                          1
# strand                              .                          .
# thickStart                   52848300                   11465980
# thickEnd                     52848450                   11466130
# itemRgb                       255,0,0                    255,0,0
# SE_chrom                            .                          .
# SE_start                           -1                         -1
# SE_end                             -1                         -1
# SE_name                             .                          .
# SE_score                           -1                         -1
#
#                                 38628                      38629  \
# chrom                           chr12                       chr5
# start                        54820681                  121647840
# end                          54823625                  121647990
# name        Proximal-Prediction-18629  Proximal-Prediction-18630
# score                               1                          1
# strand                              .                          .
# thickStart                   54821900                  121647840
# thickEnd                     54822050                  121647990
# itemRgb                       255,0,0                    255,0,0
# SE_chrom                            .                          .
# SE_start                           -1                         -1
# SE_end                             -1                         -1
# SE_name                             .                          .
# SE_score                           -1                         -1
#
#                                 38630                      38631  \
# chrom                           chr16                      chr11
# start                        67193280                   44117140
# end                          67194085                   44117290
# name        Proximal-Prediction-18631  Proximal-Prediction-18632
# score                               1                          1
# strand                              .                          .
# thickStart                   67193780                   44117140
# thickEnd                     67193930                   44117290
# itemRgb                       255,0,0                    255,0,0
# SE_chrom                            .                          .
# SE_start                           -1                         -1
# SE_end                             -1                         -1
# SE_name                             .                          .
# SE_score                           -1                         -1
#
#                                 38632                      38633
# chrom                           chr18                      chr16
# start                        24127860                   11762160
# end                          24128010                   11762310
# name        Proximal-Prediction-18633  Proximal-Prediction-18634
# score                               1                          1
# strand                              .                          .
# thickStart                   24127860                   11762160
# thickEnd                     24128010                   11762310
# itemRgb                       255,0,0                    255,0,0
# SE_chrom                            .                          .
# SE_start                           -1                         -1
# SE_end                             -1                         -1
# SE_name                             .                          .
# SE_score                           -1                         -1
#
# [14 rows x 38634 columns]

# %%
# add extra info from the dbSUPER csv
ag_dbSUPER_details = dbSUPER_filepath + 'adrenal_gland_dbSUPER_sample_full.csv'
ag_dbSUPER_details_df = pd.read_csv(ag_dbSUPER_details)
ag_dbSUPER_details_df.head()
# Out:
#          ID  Chrom      Start        End    Size Associated Gene   Method  \
# 0  SE_00853   chr2  218654125  218872122  217997            TNS1  H3K27ac
# 1  SE_00854   chr1   21563495   21672486  108991            ECE1  H3K27ac
# 2  SE_00855  chr17   75345812   75474356  128544         MIR4316  H3K27ac
# 3  SE_00856  chr19    3335211    3466265  131054            NFIC  H3K27ac
# 4  SE_00857  chr10   80826604   80955865  129261           ZMIZ1  H3K27ac
#
#    Rank    Cell/Tissue Genome  UCSC  Unnamed: 11
# 0     1  Adrenal Gland  Human   NaN     24119843
# 1     2  Adrenal Gland  Human   NaN     24119843
# 2     3  Adrenal Gland  Human   NaN     24119843
# 3     4  Adrenal Gland  Human   NaN     24119843
# 4     5  Adrenal Gland  Human   NaN     24119843

# %%
ag_overlap_detail_df = ag_overlap_df.merge(
    ag_dbSUPER_details_df[['ID', 'Size', 'Associated Gene', 'Method', 'Rank', 'Cell/Tissue']], 
    how='left', left_on='SE_name', right_on='ID')

# %%
len(ag_overlap_detail_df)
# Out:
# 38634

# %%
ag_overlap_detail_df
ag_overlap_detail_df = ag_overlap_detail_df.drop('thickStart', axis=1)
ag_overlap_detail_df = ag_overlap_detail_df.drop('thickEnd', axis=1)
ag_overlap_detail_df = ag_overlap_detail_df.drop('itemRgb', axis=1)
ag_overlap_detail_df = ag_overlap_detail_df.drop('ID', axis=1)
ag_overlap_detail_df = ag_overlap_detail_df.drop('Rank', axis=1)

ag_overlap_detail_df.columns = ['chrom', 'start', 'end', 'name', 'score', 'strand', 'SE_chrom', \
 'SE_start', 'SE_end', 'SE_name', 'SE_score', 'SE_size', 'SE_associated_gene', 'SE_method', 'SE_biosample']
ag_overlap_detail_df.T
# Out:
#                                   0                    1      \
# chrom                             chr13                chr14
# start                          34114318             35800256
# end                            34118911             35812312
# name                Distal-Prediction-1  Distal-Prediction-2
# score                                 1                    1
# strand                                .                    .
# SE_chrom                              .                chr14
# SE_start                             -1             35800648
# SE_end                               -1             35813368
# SE_name                               .             SE_01165
# SE_score                             -1                  313
# SE_size                             NaN                12720
# SE_associated_gene                  NaN                PSMA6
# SE_method                           NaN              H3K27ac
# SE_biosample                        NaN        Adrenal Gland
#
#                                   2                    3      \
# chrom                             chr16                chr14
# start                          22200146             62025090
# end                            22205387             62033524
# name                Distal-Prediction-3  Distal-Prediction-4
# score                                 1                    1
# strand                                .                    .
# SE_chrom                              .                chr14
# SE_start                             -1             61977862
# SE_end                               -1             62062455
# SE_name                               .             SE_00951
# SE_score                             -1                   99
# SE_size                             NaN                84593
# SE_associated_gene                  NaN                HIF1A
# SE_method                           NaN              H3K27ac
# SE_biosample                        NaN        Adrenal Gland
#
#                                   4                    5      \
# chrom                             chr12                chr19
# start                           8178209             18413303
# end                             8180468             18418380
# name                Distal-Prediction-5  Distal-Prediction-6
# score                                 1                    1
# strand                                .                    .
# SE_chrom                              .                    .
# SE_start                             -1                   -1
# SE_end                               -1                   -1
# SE_name                               .                    .
# SE_score                             -1                   -1
# SE_size                             NaN                  NaN
# SE_associated_gene                  NaN                  NaN
# SE_method                           NaN                  NaN
# SE_biosample                        NaN                  NaN
#
#                                   6                    7      \
# chrom                             chr17                chr19
# start                          41436643              2057975
# end                            41439942              2063141
# name                Distal-Prediction-7  Distal-Prediction-8
# score                                 1                    1
# strand                                .                    .
# SE_chrom                              .                chr19
# SE_start                             -1              2031672
# SE_end                               -1              2094175
# SE_name                               .             SE_00877
# SE_score                             -1                   25
# SE_size                             NaN                62503
# SE_associated_gene                  NaN                MKNK2
# SE_method                           NaN              H3K27ac
# SE_biosample                        NaN        Adrenal Gland
#
#                                   8                     9      \
# chrom                              chr7                 chr19
# start                         130008428              39891316
# end                           130015073              39895380
# name                Distal-Prediction-9  Distal-Prediction-10
# score                                 1                     1
# strand                                .                     .
# SE_chrom                              .                 chr19
# SE_start                             -1              39887759
# SE_end                               -1              39902523
# SE_name                               .              SE_01016
# SE_score                             -1                   164
# SE_size                             NaN                 14764
# SE_associated_gene                  NaN                 ZFP36
# SE_method                           NaN               H3K27ac
# SE_biosample                        NaN         Adrenal Gland
#
#                               ...                                  38624  \
# chrom                         ...                                  chr19
# start                         ...                               46880463
# end                           ...                               46882005
# name                          ...              Proximal-Prediction-18625
# score                         ...                                      1
# strand                        ...                                      .
# SE_chrom                      ...                                      .
# SE_start                      ...                                     -1
# SE_end                        ...                                     -1
# SE_name                       ...                                      .
# SE_score                      ...                                     -1
# SE_size                       ...                                    NaN
# SE_associated_gene            ...                                    NaN
# SE_method                     ...                                    NaN
# SE_biosample                  ...                                    NaN
#
#                                         38625                      38626  \
# chrom                                   chr19                      chr17
# start                                45260914                   52847987
# end                                  45261457                   52848805
# name                Proximal-Prediction-18626  Proximal-Prediction-18627
# score                                       1                          1
# strand                                      .                          .
# SE_chrom                                chr19                          .
# SE_start                             45240079                         -1
# SE_end                               45263101                         -1
# SE_name                              SE_01042                          .
# SE_score                                  190                         -1
# SE_size                                 23022                        NaN
# SE_associated_gene                       BCL3                        NaN
# SE_method                             H3K27ac                        NaN
# SE_biosample                    Adrenal Gland                        NaN
#
#                                         38627                      38628  \
# chrom                                   chr19                      chr12
# start                                11465980                   54820681
# end                                  11466130                   54823625
# name                Proximal-Prediction-18628  Proximal-Prediction-18629
# score                                       1                          1
# strand                                      .                          .
# SE_chrom                                    .                          .
# SE_start                                   -1                         -1
# SE_end                                     -1                         -1
# SE_name                                     .                          .
# SE_score                                   -1                         -1
# SE_size                                   NaN                        NaN
# SE_associated_gene                        NaN                        NaN
# SE_method                                 NaN                        NaN
# SE_biosample                              NaN                        NaN
#
#                                         38629                      38630  \
# chrom                                    chr5                      chr16
# start                               121647840                   67193280
# end                                 121647990                   67194085
# name                Proximal-Prediction-18630  Proximal-Prediction-18631
# score                                       1                          1
# strand                                      .                          .
# SE_chrom                                    .                          .
# SE_start                                   -1                         -1
# SE_end                                     -1                         -1
# SE_name                                     .                          .
# SE_score                                   -1                         -1
# SE_size                                   NaN                        NaN
# SE_associated_gene                        NaN                        NaN
# SE_method                                 NaN                        NaN
# SE_biosample                              NaN                        NaN
#
#                                         38631                      38632  \
# chrom                                   chr11                      chr18
# start                                44117140                   24127860
# end                                  44117290                   24128010
# name                Proximal-Prediction-18632  Proximal-Prediction-18633
# score                                       1                          1
# strand                                      .                          .
# SE_chrom                                    .                          .
# SE_start                                   -1                         -1
# SE_end                                     -1                         -1
# SE_name                                     .                          .
# SE_score                                   -1                         -1
# SE_size                                   NaN                        NaN
# SE_associated_gene                        NaN                        NaN
# SE_method                                 NaN                        NaN
# SE_biosample                              NaN                        NaN
#
#                                         38633
# chrom                                   chr16
# start                                11762160
# end                                  11762310
# name                Proximal-Prediction-18634
# score                                       1
# strand                                      .
# SE_chrom                                    .
# SE_start                                   -1
# SE_end                                     -1
# SE_name                                     .
# SE_score                                   -1
# SE_size                                   NaN
# SE_associated_gene                        NaN
# SE_method                                 NaN
# SE_biosample                              NaN
#
# [15 rows x 38634 columns]

# %%
dbSUPER_download_path = '/Users/manuel/development/thesis/download/dbSUPER/all_hg19_bed.bed'
full_hg19_dbSUPER = BedTool(dbSUPER_download_path)

# %%
len(full_hg19_dbSUPER)
# Out:
# 65950

# %% [markdown]
# ## dbSUPER downloader

# %%
import csv
import urllib
from lxml import html
from bs4 import BeautifulSoup

dbSUPER_FULL_url = 'http://bioinfo.au.tsinghua.edu.cn/dbsuper/\
adv_search.php?genome=hg19&cell_type%5B%5D=C_001&cell_type%5B%5D=C_002&cell_type%5B%5D=C_003\
&cell_type%5B%5D=C_004&cell_type%5B%5D=C_005&cell_type%5B%5D=C_006&cell_type%5B%5D=C_007\
&cell_type%5B%5D=C_008&cell_type%5B%5D=C_009&cell_type%5B%5D=C_010&cell_type%5B%5D=C_011\
&cell_type%5B%5D=C_012&cell_type%5B%5D=C_013&cell_type%5B%5D=C_014&cell_type%5B%5D=C_015\
&cell_type%5B%5D=C_016&cell_type%5B%5D=C_017&cell_type%5B%5D=C_018&cell_type%5B%5D=C_019\
&cell_type%5B%5D=C_020&cell_type%5B%5D=C_021&cell_type%5B%5D=C_022&cell_type%5B%5D=C_023\
&cell_type%5B%5D=C_024&cell_type%5B%5D=C_025&cell_type%5B%5D=C_026&cell_type%5B%5D=C_027\
&cell_type%5B%5D=C_028&cell_type%5B%5D=C_029&cell_type%5B%5D=C_030&cell_type%5B%5D=C_031\
&cell_type%5B%5D=C_032&cell_type%5B%5D=C_033&cell_type%5B%5D=C_034&cell_type%5B%5D=C_035\
&cell_type%5B%5D=C_036&cell_type%5B%5D=C_037&cell_type%5B%5D=C_038&cell_type%5B%5D=C_039\
&cell_type%5B%5D=C_096&cell_type%5B%5D=C_040&cell_type%5B%5D=C_041&cell_type%5B%5D=C_042\
&cell_type%5B%5D=C_043&cell_type%5B%5D=C_044&cell_type%5B%5D=C_045&cell_type%5B%5D=C_046\
&cell_type%5B%5D=C_047&cell_type%5B%5D=C_100&cell_type%5B%5D=C_048&cell_type%5B%5D=C_049\
&cell_type%5B%5D=C_050&cell_type%5B%5D=C_128&cell_type%5B%5D=C_097&cell_type%5B%5D=C_051\
&cell_type%5B%5D=C_052&cell_type%5B%5D=C_053&cell_type%5B%5D=C_054&cell_type%5B%5D=C_055\
&cell_type%5B%5D=C_103&cell_type%5B%5D=C_056&cell_type%5B%5D=C_057&cell_type%5B%5D=C_058\
&cell_type%5B%5D=C_059&cell_type%5B%5D=C_060&cell_type%5B%5D=C_061&cell_type%5B%5D=C_062\
&cell_type%5B%5D=C_063&cell_type%5B%5D=C_093&cell_type%5B%5D=C_094&cell_type%5B%5D=C_095\
&cell_type%5B%5D=C_064&cell_type%5B%5D=C_065&cell_type%5B%5D=C_102&cell_type%5B%5D=C_101\
&cell_type%5B%5D=C_066&cell_type%5B%5D=C_104&cell_type%5B%5D=C_067&cell_type%5B%5D=C_068\
&cell_type%5B%5D=C_069&cell_type%5B%5D=C_070&cell_type%5B%5D=C_071&cell_type%5B%5D=C_105\
&cell_type%5B%5D=C_072&cell_type%5B%5D=C_073&cell_type%5B%5D=C_074&cell_type%5B%5D=C_075\
&cell_type%5B%5D=C_076&cell_type%5B%5D=C_077&cell_type%5B%5D=C_078&cell_type%5B%5D=C_079\
&cell_type%5B%5D=C_080&cell_type%5B%5D=C_081&cell_type%5B%5D=C_108&cell_type%5B%5D=C_109\
&cell_type%5B%5D=C_082&cell_type%5B%5D=C_098&cell_type%5B%5D=C_099&cell_type%5B%5D=C_083\
&cell_type%5B%5D=C_084&cell_type%5B%5D=C_085&cell_type%5B%5D=C_086&gene=&locus=&method=&submit=1'

dbSUPER_url = 'http://bioinfo.au.tsinghua.edu.cn/dbsuper/ses.php?genome=hg19&cell_type=C_005'
# page = html.fromstring(urllib.request.urlopen(dbSUPER_url).read())
headers = {'accept': 'application/json'}
response = requests.get(dbSUPER_FULL_url, headers=headers)
html = response.text

soup = BeautifulSoup(html, 'lxml')
table = soup.find_all('table')[0]

# %%
columns = []

htr = table.find_all('tr')[0]
htds = htr.find_all('th')[0:10]
columns = [elem.text for elem in htds]

rows = []
for tr in table.find_all('tr')[1:]:
    tds = tr.find_all('td')[0:10]
    rows.append([elem.text.strip() for elem in tds])

# %%
columns
# Out:
# ['ID',
#  'Chrom',
#  'Start',
#  'End',
#  'Size',
#  'Associated Gene',
#  'Method',
#  'Rank',
#  'Cell/Tissue',
#  'Genome']

# %%
rows[0]
# Out:
# ['SE_00001',
#  'chr1',
#  '120485363',
#  '120615071',
#  '129708',
#  'NOTCH2',
#  'H3K27ac',
#  '1',
#  'Adipose Nuclei',
#  'Human']

# %%
len(rows)
# Out:
# 69205

# %%
temp_df = pd.DataFrame.from_records(rows, columns=columns)
len(temp_df)
# Out:
# 69205

# %%
temp_df
# Out:
#              ID  Chrom      Start        End    Size Associated Gene   Method  \
# 0      SE_00001   chr1  120485363  120615071  129708          NOTCH2  H3K27ac
# 1      SE_00002  chr13  110838836  111112228  273392          COL4A2  H3K27ac
# 2      SE_00003   chr1  145206326  145293008   86682        NOTCH2NL  H3K27ac
# 3      SE_00004   chr5  158117077  158371526  254449            EBF1  H3K27ac
# 4      SE_00005   chr2  218548183  218895526  347343            TNS1  H3K27ac
# 5      SE_00006   chr2   54586565   54904699  318134          SPTBN1  H3K27ac
# 6      SE_00007   chr6  112420456  112652968  232512           LAMA4  H3K27ac
# 7      SE_00008   chr3   12327760   12522419  194659           PPARG  H3K27ac
# 8      SE_00009   chr1   12455848   12698932  243084           DHRS3  H3K27ac
# 9      SE_00010   chr8   30239218   30455499  216281           RBPMS  H3K27ac
# 10     SE_00011  chr11  111468184  111670113  201929         PPP2R1B  H3K27ac
# 11     SE_00012  chr10   82143428   82297600  154172         TSPAN14  H3K27ac
# 12     SE_00013   chr2  145147464  145289272  141808            ZEB2  H3K27ac
# 13     SE_00014   chr1   92148226   92358240  210014          TGFBR3  H3K27ac
# 14     SE_00015  chr10  114708122  114899787  191665          TCF7L2  H3K27ac
# 15     SE_00016  chr10   97067610   97208276  140666          PDLIM1  H3K27ac
# 16     SE_00017   chr9   14132520   14325750  193230            NFIB  H3K27ac
# 17     SE_00018   chr7  116124962  116229755  104793            CAV1  H3K27ac
# 18     SE_00019  chr22   46436313   46491627   55314           PRR34  H3K27ac
# 19     SE_00020  chr15   62681468   62918670  237202        MGC15885  H3K27ac
# 20     SE_00021   chr9  124030416  124136617  106201             GSN  H3K27ac
# 21     SE_00022   chr9  112747903  112917636  169733           AKAP2  H3K27ac
# 22     SE_00023   chr5  158457028  158534580   77552            EBF1  H3K27ac
# 23     SE_00024  chr19   13106663   13216504  109841            LYL1  H3K27ac
# 24     SE_00025   chr3  127414600  127543388  128788            MGLL  H3K27ac
# 25     SE_00026   chr7   80212197   80311799   99602            CD36  H3K27ac
# 26     SE_00027   chr1   61541623   61748432  206809            NFIA  H3K27ac
# 27     SE_00028  chr11   65250988   65277615   26627          MALAT1  H3K27ac
# 28     SE_00029   chr8   62494289   62637126  142837            ASPH  H3K27ac
# 29     SE_00030   chr2    1631156    1749787  118631            PXDN  H3K27ac
# ...         ...    ...        ...        ...     ...             ...      ...
# 69175  SE_69177  chr12    7033372    7038711    5339            ATN1  H3K27ac
# 69176  SE_69178  chr11  121336398  121353961   17563           SORL1  H3K27ac
# 69177  SE_69179  chr18   46440916   46479872   38956           SMAD7  H3K27ac
# 69178  SE_69180   chr4  113667474  113684577   17103            ANK2  H3K27ac
# 69179  SE_69181  chr16     428546     434719    6173          TMEM8A  H3K27ac
# 69180  SE_69182   chr6   34096743   34107755   11012            GRM4  H3K27ac
# 69181  SE_69183  chr19   38456778   38516435   59657         SIPA1L3  H3K27ac
# 69182  SE_69184   chr5  154133797  154137409    3612           LARP1  H3K27ac
# 69183  SE_69185  chr11  118485802  118507131   21329          PHLDB1  H3K27ac
# 69184  SE_69186   chr3    3840190    3844230    4040           LRRN1  H3K27ac
# 69185  SE_69187   chr2   61763341   61766870    3529            XPO1  H3K27ac
# 69186  SE_69188  chr20   25506794   25529786   22992            NINL  H3K27ac
# 69187  SE_69189   chr1   27018642   27024740    6098          ARID1A  H3K27ac
# 69188  SE_69190  chr11   75014207   75056753   42546          MIR326  H3K27ac
# 69189  SE_69191   chr7  100025457  100029727    4270           MEPCE  H3K27ac
# 69190  SE_69192   chr1   38733857   38738524    4667         MIR3659  H3K27ac
# 69191  SE_69193  chr13   80910874   80917530    6656           SPRY2  H3K27ac
# 69192  SE_69194  chr12   53885789   53896049   10260         MAP3K12  H3K27ac
# 69193  SE_69195   chr3   61545352   61550806    5454           PTPRG  H3K27ac
# 69194  SE_69196  chr11   69513908   69527805   13897           FGF19  H3K27ac
# 69195  SE_69197  chr11    3158961    3182564   23603          OSBPL5  H3K27ac
# 69196  SE_69198  chr17   65746656   65753367    6711        SNORA38B  H3K27ac
# 69197  SE_69199  chr20   62579170   62591650   12480       UCKL1-AS1  H3K27ac
# 69198  SE_69200   chrX   39949099   39969242   20143            BCOR  H3K27ac
# 69199  SE_69201   chrX   41331328   41336670    5342             NYX  H3K27ac
# 69200  SE_69202   chr4  113625864  113632734    6870         MIR302B  H3K27ac
# 69201  SE_69203  chr17   42616770   42637296   20526            FZD2  H3K27ac
# 69202  SE_69204  chr12  117472669  117501818   29149            TESC  H3K27ac
# 69203  SE_69205  chr19   47728521   47732531    4010         MIR3191  H3K27ac
# 69204  SE_69206   chr7    2561462    2571612   10150            LFNG  H3K27ac
#
#       Rank     Cell/Tissue Genome
# 0        1  Adipose Nuclei  Human
# 1        2  Adipose Nuclei  Human
# 2        3  Adipose Nuclei  Human
# 3        4  Adipose Nuclei  Human
# 4        5  Adipose Nuclei  Human
# 5        6  Adipose Nuclei  Human
# 6        7  Adipose Nuclei  Human
# 7        8  Adipose Nuclei  Human
# 8        9  Adipose Nuclei  Human
# 9       10  Adipose Nuclei  Human
# 10      11  Adipose Nuclei  Human
# 11      12  Adipose Nuclei  Human
# 12      13  Adipose Nuclei  Human
# 13      14  Adipose Nuclei  Human
# 14      15  Adipose Nuclei  Human
# 15      16  Adipose Nuclei  Human
# 16      17  Adipose Nuclei  Human
# 17      18  Adipose Nuclei  Human
# 18      19  Adipose Nuclei  Human
# 19      20  Adipose Nuclei  Human
# 20      21  Adipose Nuclei  Human
# 21      22  Adipose Nuclei  Human
# 22      23  Adipose Nuclei  Human
# 23      24  Adipose Nuclei  Human
# 24      25  Adipose Nuclei  Human
# 25      26  Adipose Nuclei  Human
# 26      27  Adipose Nuclei  Human
# 27      28  Adipose Nuclei  Human
# 28      29  Adipose Nuclei  Human
# 29      30  Adipose Nuclei  Human
# ...    ...             ...    ...
# 69175  506              H9  Human
# 69176  507              H9  Human
# 69177  508              H9  Human
# 69178  509              H9  Human
# 69179  510              H9  Human
# 69180  511              H9  Human
# 69181  512              H9  Human
# 69182  513              H9  Human
# 69183  514              H9  Human
# 69184  515              H9  Human
# 69185  516              H9  Human
# 69186  517              H9  Human
# 69187  518              H9  Human
# 69188  519              H9  Human
# 69189  520              H9  Human
# 69190  521              H9  Human
# 69191  522              H9  Human
# 69192  523              H9  Human
# 69193  524              H9  Human
# 69194  525              H9  Human
# 69195  526              H9  Human
# 69196  527              H9  Human
# 69197  528              H9  Human
# 69198  529              H9  Human
# 69199  530              H9  Human
# 69200  531              H9  Human
# 69201  532              H9  Human
# 69202  533              H9  Human
# 69203  534              H9  Human
# 69204  535              H9  Human
#
# [69205 rows x 10 columns]
