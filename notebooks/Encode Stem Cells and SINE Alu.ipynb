# %%
import pandas as pd

store = pd.HDFStore('../storage/encode_repeatmasker_stats.hdf')

# %%
store.keys()
# Out:
# ['/overlap_hg19_DNase_H3K27ac_tissue_SINE_Alu',
#  '/reldist_hg19_DNase_H3K27ac_stem_cell_SINE_Alu',
#  '/reldist_hg19_DNase_H3K27ac_tissue_SINE_Alu']

# %%
store.close()

# %% [markdown]
# ## Stem Cells

# %%
import seaborn as sns
# %matplotlib inline
import pandas as pd

# %%
stem_df = pd.read_hdf('../storage/encode_repeatmasker_stats.hdf', 'reldist_hg19_DNase_H3K27ac_stem_cell_SINE_Alu')

# %%
stem_df.T
# Out:
#                                        0                   1    \
# encyclopedia                        ENCODE              ENCODE
# biosample_type                   stem cell           stem cell
# biosample_name          neuronal stem cell  neuronal stem cell
# ovlp_encyclopedia                 SINE_Alu            SINE_Alu
# encyclopedia_size                    46114               46114
# ovlp_encyclopedia_size         1.17725e+06         1.17725e+06
# reldist                                  0                0.01
# ovlp_count                              59                 100
# ovlp_fraction                        0.001               0.002
#
#                                        2                   3    \
# encyclopedia                        ENCODE              ENCODE
# biosample_type                   stem cell           stem cell
# biosample_name          neuronal stem cell  neuronal stem cell
# ovlp_encyclopedia                 SINE_Alu            SINE_Alu
# encyclopedia_size                    46114               46114
# ovlp_encyclopedia_size         1.17725e+06         1.17725e+06
# reldist                               0.02                0.03
# ovlp_count                             181                 248
# ovlp_fraction                        0.004               0.005
#
#                                        4                   5    \
# encyclopedia                        ENCODE              ENCODE
# biosample_type                   stem cell           stem cell
# biosample_name          neuronal stem cell  neuronal stem cell
# ovlp_encyclopedia                 SINE_Alu            SINE_Alu
# encyclopedia_size                    46114               46114
# ovlp_encyclopedia_size         1.17725e+06         1.17725e+06
# reldist                               0.04                0.05
# ovlp_count                             266                 386
# ovlp_fraction                        0.006               0.008
#
#                                        6                   7    \
# encyclopedia                        ENCODE              ENCODE
# biosample_type                   stem cell           stem cell
# biosample_name          neuronal stem cell  neuronal stem cell
# ovlp_encyclopedia                 SINE_Alu            SINE_Alu
# encyclopedia_size                    46114               46114
# ovlp_encyclopedia_size         1.17725e+06         1.17725e+06
# reldist                               0.06                0.07
# ovlp_count                             424                 468
# ovlp_fraction                        0.009                0.01
#
#                                        8                   9       ...       \
# encyclopedia                        ENCODE              ENCODE     ...
# biosample_type                   stem cell           stem cell     ...
# biosample_name          neuronal stem cell  neuronal stem cell     ...
# ovlp_encyclopedia                 SINE_Alu            SINE_Alu     ...
# encyclopedia_size                    46114               46114     ...
# ovlp_encyclopedia_size         1.17725e+06         1.17725e+06     ...
# reldist                               0.08                0.09     ...
# ovlp_count                             516                 615     ...
# ovlp_fraction                        0.011               0.013     ...
#
#                                 602          603          604          605  \
# encyclopedia                 ENCODE       ENCODE       ENCODE       ENCODE
# biosample_type            stem cell    stem cell    stem cell    stem cell
# biosample_name                   H9           H9           H9           H9
# ovlp_encyclopedia          SHUFFLED     SHUFFLED     SHUFFLED     SHUFFLED
# encyclopedia_size             42494        42494        42494        42494
# ovlp_encyclopedia_size  1.17725e+06  1.17725e+06  1.17725e+06  1.17725e+06
# reldist                        0.41         0.42         0.43         0.44
# ovlp_count                      811          834          862          869
# ovlp_fraction                 0.019         0.02         0.02         0.02
#
#                                 606          607          608          609  \
# encyclopedia                 ENCODE       ENCODE       ENCODE       ENCODE
# biosample_type            stem cell    stem cell    stem cell    stem cell
# biosample_name                   H9           H9           H9           H9
# ovlp_encyclopedia          SHUFFLED     SHUFFLED     SHUFFLED     SHUFFLED
# encyclopedia_size             42494        42494        42494        42494
# ovlp_encyclopedia_size  1.17725e+06  1.17725e+06  1.17725e+06  1.17725e+06
# reldist                        0.45         0.46         0.47         0.48
# ovlp_count                      854          881          782          851
# ovlp_fraction                  0.02        0.021        0.018         0.02
#
#                                 610          611
# encyclopedia                 ENCODE       ENCODE
# biosample_type            stem cell    stem cell
# biosample_name                   H9           H9
# ovlp_encyclopedia          SHUFFLED     SHUFFLED
# encyclopedia_size             42494        42494
# ovlp_encyclopedia_size  1.17725e+06  1.17725e+06
# reldist                        0.49          0.5
# ovlp_count                      854            6
# ovlp_fraction                  0.02            0
#
# [9 rows x 612 columns]

# %%
stem_df = stem_df.query("ovlp_fraction > 0")

# %%
sns.set(style="whitegrid")
sns.set_context("poster", font_scale=0.8, rc={"lines.linewidth": 0.8})

g = sns.FacetGrid(stem_df, col="biosample_name", hue="ovlp_encyclopedia", col_wrap=2, size=8)
g.map(sns.pointplot, "reldist", "ovlp_fraction", capsize=.2, size=6, aspect=1)
g.add_legend();

# %%
stem_ovlp_df = pd.read_hdf('../storage/encode_repeatmasker_stats.hdf', 'overlap_hg19_DNase_H3K27ac_stem_cell_SINE_Alu')

# %%
stem_ovlp_df.T
# Out:
#                                        0                   1    \
# biosample_name          neuronal stem cell  neuronal stem cell
# biosample_type                   stem cell           stem cell
# encyclopedia                        ENCODE              ENCODE
# encyclopedia_size                    46114               46114
# fisher_left_p                          NaN                 NaN
# fisher_oddsratio                       NaN                 NaN
# fisher_right_p                           1                   1
# fisher_two_p                           NaN                 NaN
# jaccard                         0.00199134          0.00152832
# min_ovlp                              0.05                 0.1
# ovlp_count                            3509                2393
# ovlp_encyclopedia                 SINE_Alu            SINE_Alu
# ovlp_encyclopedia_size         1.17725e+06         1.17725e+06
# z_random                                 0                   0
# z_shuffled                               0                   0
#
#                                        2                   3    \
# biosample_name          neuronal stem cell  neuronal stem cell
# biosample_type                   stem cell           stem cell
# encyclopedia                        ENCODE              ENCODE
# encyclopedia_size                    46114               46114
# fisher_left_p                          NaN                 NaN
# fisher_oddsratio                       NaN                 NaN
# fisher_right_p                           1                   1
# fisher_two_p                           NaN                 NaN
# jaccard                         0.00102462         0.000660686
# min_ovlp                              0.15                 0.2
# ovlp_count                            1525                 973
# ovlp_encyclopedia                 SINE_Alu            SINE_Alu
# ovlp_encyclopedia_size         1.17725e+06         1.17725e+06
# z_random                                 0                   0
# z_shuffled                               0                   0
#
#                                        4                   5    \
# biosample_name          neuronal stem cell  neuronal stem cell
# biosample_type                   stem cell           stem cell
# encyclopedia                        ENCODE              ENCODE
# encyclopedia_size                    46114               46114
# fisher_left_p                          NaN                 NaN
# fisher_oddsratio                       NaN                 NaN
# fisher_right_p                           1                   1
# fisher_two_p                           NaN                 NaN
# jaccard                        0.000416133         0.000260673
# min_ovlp                              0.25                 0.3
# ovlp_count                             623                 401
# ovlp_encyclopedia                 SINE_Alu            SINE_Alu
# ovlp_encyclopedia_size         1.17725e+06         1.17725e+06
# z_random                                 0                   0
# z_shuffled                               0                   0
#
#                                        6                   7    \
# biosample_name          neuronal stem cell  neuronal stem cell
# biosample_type                   stem cell           stem cell
# encyclopedia                        ENCODE              ENCODE
# encyclopedia_size                    46114               46114
# fisher_left_p                          NaN                 NaN
# fisher_oddsratio                       NaN                 NaN
# fisher_right_p                           1                   1
# fisher_two_p                           NaN                 NaN
# jaccard                         0.00015887         7.57082e-05
# min_ovlp                              0.35                 0.4
# ovlp_count                             266                 159
# ovlp_encyclopedia                 SINE_Alu            SINE_Alu
# ovlp_encyclopedia_size         1.17725e+06         1.17725e+06
# z_random                                 0                   0
# z_shuffled                               0                   0
#
#                                        8                   9       ...       \
# biosample_name          neuronal stem cell  neuronal stem cell     ...
# biosample_type                   stem cell           stem cell     ...
# encyclopedia                        ENCODE              ENCODE     ...
# encyclopedia_size                    46114               46114     ...
# fisher_left_p                          NaN                 NaN     ...
# fisher_oddsratio                       NaN                 NaN     ...
# fisher_right_p                           1                   1     ...
# fisher_two_p                           NaN                 NaN     ...
# jaccard                        4.74172e-05         3.88571e-05     ...
# min_ovlp                              0.45                 0.5     ...
# ovlp_count                             117                 100     ...
# ovlp_encyclopedia                 SINE_Alu            SINE_Alu     ...
# ovlp_encyclopedia_size         1.17725e+06         1.17725e+06     ...
# z_random                                 0                   0     ...
# z_shuffled                               0                   0     ...
#
#                                 218          219          220          221  \
# biosample_name                   H9           H9           H9           H9
# biosample_type            stem cell    stem cell    stem cell    stem cell
# encyclopedia                 ENCODE       ENCODE       ENCODE       ENCODE
# encyclopedia_size             42494        42494        42494        42494
# fisher_left_p                     0            0            0            0
# fisher_oddsratio              0.166        0.152        0.141        0.129
# fisher_right_p                    1            1            1            1
# fisher_two_p                      0            0            0            0
# jaccard                  0.00126424   0.00114173   0.00106409  0.000985658
# min_ovlp                        0.5         0.55          0.6         0.65
# ovlp_count                     2706         2489         2320         2130
# ovlp_encyclopedia          SHUFFLED     SHUFFLED     SHUFFLED     SHUFFLED
# ovlp_encyclopedia_size  1.17725e+06  1.17725e+06  1.17725e+06  1.17725e+06
# z_random                        NaN          NaN          NaN          NaN
# z_shuffled                      NaN          NaN          NaN          NaN
#
#                                 222          223          224          225  \
# biosample_name                   H9           H9           H9           H9
# biosample_type            stem cell    stem cell    stem cell    stem cell
# encyclopedia                 ENCODE       ENCODE       ENCODE       ENCODE
# encyclopedia_size             42494        42494        42494        42494
# fisher_left_p                     0            0            0            0
# fisher_oddsratio              0.119        0.108        0.099        0.088
# fisher_right_p                    1            1            1            1
# fisher_two_p                      0            0            0            0
# jaccard                  0.00091159  0.000838111  0.000779076  0.000707918
# min_ovlp                        0.7         0.75          0.8         0.85
# ovlp_count                     1977         1809         1665         1480
# ovlp_encyclopedia          SHUFFLED     SHUFFLED     SHUFFLED     SHUFFLED
# ovlp_encyclopedia_size  1.17725e+06  1.17725e+06  1.17725e+06  1.17725e+06
# z_random                        NaN          NaN          NaN          NaN
# z_shuffled                      NaN          NaN          NaN          NaN
#
#                                 226          227
# biosample_name                   H9           H9
# biosample_type            stem cell    stem cell
# encyclopedia                 ENCODE       ENCODE
# encyclopedia_size             42494        42494
# fisher_left_p                     0            0
# fisher_oddsratio              0.081        0.073
# fisher_right_p                    1            1
# fisher_two_p                      0            0
# jaccard                 0.000662626  0.000610506
# min_ovlp                        0.9         0.95
# ovlp_count                     1371         1245
# ovlp_encyclopedia          SHUFFLED     SHUFFLED
# ovlp_encyclopedia_size  1.17725e+06  1.17725e+06
# z_random                        NaN          NaN
# z_shuffled                      NaN          NaN
#
# [15 rows x 228 columns]

# %%
stem_ovlp_df['biosample_name'].unique()
# Out:
# array(['neuronal stem cell', 'H1-hESC', 'H9'], dtype=object)

# %%
import seaborn as sns
# %matplotlib inline

# %%
sns.set(style="whitegrid")
sns.set_context("poster", font_scale=0.7, rc={"lines.linewidth": 1})

g = sns.FacetGrid(stem_ovlp_df, col="biosample_name", hue="ovlp_encyclopedia", col_wrap=2, size=7)
g.map(sns.pointplot, "min_ovlp", "jaccard", capsize=.2, size=6, aspect=1)
g.add_legend();

# %%
sns.set(style="whitegrid")
sns.set_context("poster", font_scale=0.8, rc={"lines.linewidth": 0.8})

g = sns.FacetGrid(stem_ovlp_df, col="biosample_name", hue="ovlp_encyclopedia", col_wrap=2, size=7)
g.map(sns.pointplot, "min_ovlp", "fisher_right_p", capsize=.2, size=6, aspect=1)
g.add_legend();
