# %%
import pandas as pd

store = pd.HDFStore('../storage/encode_repeatmasker_stats.hdf')

# %%
store.keys()
# Out:
# ['/overlap_hg19_DNase_H3K27ac_immortalized_cell_line_SINE_Alu',
#  '/overlap_hg19_DNase_H3K27ac_in_vitro_differentiated_cells_SINE_Alu',
#  '/overlap_hg19_DNase_H3K27ac_induced_pluripotent_stem_cell_line_SINE_Alu',
#  '/overlap_hg19_DNase_H3K27ac_primary_cell_SINE_Alu',
#  '/overlap_hg19_DNase_H3K27ac_stem_cell_SINE_Alu',
#  '/overlap_hg19_DNase_H3K27ac_tissue_SINE_Alu',
#  '/reldist_hg19_DNase_H3K27ac_immortalized_cell_line_SINE_Alu',
#  '/reldist_hg19_DNase_H3K27ac_in_vitro_differentiated_cells_SINE_Alu',
#  '/reldist_hg19_DNase_H3K27ac_induced_pluripotent_stem_cell_line_SINE_Alu',
#  '/reldist_hg19_DNase_H3K27ac_primary_cell_SINE_Alu',
#  '/reldist_hg19_DNase_H3K27ac_stem_cell_SINE_Alu',
#  '/reldist_hg19_DNase_H3K27ac_tissue_SINE_Alu']

# %%
store.close()

# %% [markdown]
# ## Primary Cells

# %%
import seaborn as sns
# %matplotlib inline
import pandas as pd

# %%
stem_df = pd.read_hdf('../storage/encode_repeatmasker_stats.hdf', 'reldist_hg19_DNase_H3K27ac_primary_cell_SINE_Alu')

# %%
stem_df.T
# Out:
#                                                             0     \
# encyclopedia                                              ENCODE
# biosample_type                                      primary cell
# biosample_name          common myeloid progenitor, CD34-positive
# ovlp_encyclopedia                                       SINE_Alu
# encyclopedia_size                                          38914
# ovlp_encyclopedia_size                               1.17725e+06
# reldist                                                        0
# ovlp_count                                                   140
# ovlp_fraction                                              0.004
#
#                                                             1     \
# encyclopedia                                              ENCODE
# biosample_type                                      primary cell
# biosample_name          common myeloid progenitor, CD34-positive
# ovlp_encyclopedia                                       SINE_Alu
# encyclopedia_size                                          38914
# ovlp_encyclopedia_size                               1.17725e+06
# reldist                                                     0.01
# ovlp_count                                                   213
# ovlp_fraction                                              0.005
#
#                                                             2     \
# encyclopedia                                              ENCODE
# biosample_type                                      primary cell
# biosample_name          common myeloid progenitor, CD34-positive
# ovlp_encyclopedia                                       SINE_Alu
# encyclopedia_size                                          38914
# ovlp_encyclopedia_size                               1.17725e+06
# reldist                                                     0.02
# ovlp_count                                                   254
# ovlp_fraction                                              0.007
#
#                                                             3     \
# encyclopedia                                              ENCODE
# biosample_type                                      primary cell
# biosample_name          common myeloid progenitor, CD34-positive
# ovlp_encyclopedia                                       SINE_Alu
# encyclopedia_size                                          38914
# ovlp_encyclopedia_size                               1.17725e+06
# reldist                                                     0.03
# ovlp_count                                                   297
# ovlp_fraction                                              0.008
#
#                                                             4     \
# encyclopedia                                              ENCODE
# biosample_type                                      primary cell
# biosample_name          common myeloid progenitor, CD34-positive
# ovlp_encyclopedia                                       SINE_Alu
# encyclopedia_size                                          38914
# ovlp_encyclopedia_size                               1.17725e+06
# reldist                                                     0.04
# ovlp_count                                                   324
# ovlp_fraction                                              0.008
#
#                                                             5     \
# encyclopedia                                              ENCODE
# biosample_type                                      primary cell
# biosample_name          common myeloid progenitor, CD34-positive
# ovlp_encyclopedia                                       SINE_Alu
# encyclopedia_size                                          38914
# ovlp_encyclopedia_size                               1.17725e+06
# reldist                                                     0.05
# ovlp_count                                                   373
# ovlp_fraction                                               0.01
#
#                                                             6     \
# encyclopedia                                              ENCODE
# biosample_type                                      primary cell
# biosample_name          common myeloid progenitor, CD34-positive
# ovlp_encyclopedia                                       SINE_Alu
# encyclopedia_size                                          38914
# ovlp_encyclopedia_size                               1.17725e+06
# reldist                                                     0.06
# ovlp_count                                                   402
# ovlp_fraction                                               0.01
#
#                                                             7     \
# encyclopedia                                              ENCODE
# biosample_type                                      primary cell
# biosample_name          common myeloid progenitor, CD34-positive
# ovlp_encyclopedia                                       SINE_Alu
# encyclopedia_size                                          38914
# ovlp_encyclopedia_size                               1.17725e+06
# reldist                                                     0.07
# ovlp_count                                                   495
# ovlp_fraction                                              0.013
#
#                                                             8     \
# encyclopedia                                              ENCODE
# biosample_type                                      primary cell
# biosample_name          common myeloid progenitor, CD34-positive
# ovlp_encyclopedia                                       SINE_Alu
# encyclopedia_size                                          38914
# ovlp_encyclopedia_size                               1.17725e+06
# reldist                                                     0.08
# ovlp_count                                                   480
# ovlp_fraction                                              0.012
#
#                                                             9     \
# encyclopedia                                              ENCODE
# biosample_type                                      primary cell
# biosample_name          common myeloid progenitor, CD34-positive
# ovlp_encyclopedia                                       SINE_Alu
# encyclopedia_size                                          38914
# ovlp_encyclopedia_size                               1.17725e+06
# reldist                                                     0.09
# ovlp_count                                                   548
# ovlp_fraction                                              0.014
#
#                                ...                          2744  \
# encyclopedia                   ...                        ENCODE
# biosample_type                 ...                  primary cell
# biosample_name                 ...           foreskin fibroblast
# ovlp_encyclopedia              ...                      SHUFFLED
# encyclopedia_size              ...                         37894
# ovlp_encyclopedia_size         ...                   1.17725e+06
# reldist                        ...                          0.41
# ovlp_count                     ...                           738
# ovlp_fraction                  ...                         0.019
#
#                                        2745                 2746  \
# encyclopedia                         ENCODE               ENCODE
# biosample_type                 primary cell         primary cell
# biosample_name          foreskin fibroblast  foreskin fibroblast
# ovlp_encyclopedia                  SHUFFLED             SHUFFLED
# encyclopedia_size                     37894                37894
# ovlp_encyclopedia_size          1.17725e+06          1.17725e+06
# reldist                                0.42                 0.43
# ovlp_count                              756                  787
# ovlp_fraction                          0.02                0.021
#
#                                        2747                 2748  \
# encyclopedia                         ENCODE               ENCODE
# biosample_type                 primary cell         primary cell
# biosample_name          foreskin fibroblast  foreskin fibroblast
# ovlp_encyclopedia                  SHUFFLED             SHUFFLED
# encyclopedia_size                     37894                37894
# ovlp_encyclopedia_size          1.17725e+06          1.17725e+06
# reldist                                0.44                 0.45
# ovlp_count                              815                  790
# ovlp_fraction                         0.022                0.021
#
#                                        2749                 2750  \
# encyclopedia                         ENCODE               ENCODE
# biosample_type                 primary cell         primary cell
# biosample_name          foreskin fibroblast  foreskin fibroblast
# ovlp_encyclopedia                  SHUFFLED             SHUFFLED
# encyclopedia_size                     37894                37894
# ovlp_encyclopedia_size          1.17725e+06          1.17725e+06
# reldist                                0.46                 0.47
# ovlp_count                              716                  712
# ovlp_fraction                         0.019                0.019
#
#                                        2751                 2752  \
# encyclopedia                         ENCODE               ENCODE
# biosample_type                 primary cell         primary cell
# biosample_name          foreskin fibroblast  foreskin fibroblast
# ovlp_encyclopedia                  SHUFFLED             SHUFFLED
# encyclopedia_size                     37894                37894
# ovlp_encyclopedia_size          1.17725e+06          1.17725e+06
# reldist                                0.48                 0.49
# ovlp_count                              720                  682
# ovlp_fraction                         0.019                0.018
#
#                                        2753
# encyclopedia                         ENCODE
# biosample_type                 primary cell
# biosample_name          foreskin fibroblast
# ovlp_encyclopedia                  SHUFFLED
# encyclopedia_size                     37894
# ovlp_encyclopedia_size          1.17725e+06
# reldist                                 0.5
# ovlp_count                                8
# ovlp_fraction                             0
#
# [9 rows x 2754 columns]

# %%
stem_df = stem_df.query("ovlp_fraction > 0")

# %%
sns.set(style="whitegrid")
sns.set_context("poster", font_scale=0.8, rc={"lines.linewidth": 0.8})

g = sns.FacetGrid(stem_df, col="biosample_name", hue="ovlp_encyclopedia", col_wrap=2, size=8)
g.map(sns.pointplot, "reldist", "ovlp_fraction", capsize=.2, size=6, aspect=1)
g.add_legend();

# %%
stem_ovlp_df = pd.read_hdf('../storage/encode_repeatmasker_stats.hdf', 'overlap_hg19_DNase_H3K27ac_primary_cell_SINE_Alu')

# %%
stem_ovlp_df.T
# Out:
#                                                             0     \
# biosample_name          common myeloid progenitor, CD34-positive
# biosample_type                                      primary cell
# encyclopedia                                              ENCODE
# encyclopedia_size                                          38914
# fisher_left_p                                                NaN
# fisher_oddsratio                                             NaN
# fisher_right_p                                                 1
# fisher_two_p                                                 NaN
# jaccard                                               0.00861767
# min_ovlp                                                    0.05
# ovlp_count                                                 13325
# ovlp_encyclopedia                                       SINE_Alu
# ovlp_encyclopedia_size                               1.17725e+06
# z_random                                                       0
# z_shuffled                                                     0
#
#                                                             1     \
# biosample_name          common myeloid progenitor, CD34-positive
# biosample_type                                      primary cell
# encyclopedia                                              ENCODE
# encyclopedia_size                                          38914
# fisher_left_p                                                NaN
# fisher_oddsratio                                             NaN
# fisher_right_p                                                 1
# fisher_two_p                                                 NaN
# jaccard                                               0.00473307
# min_ovlp                                                     0.1
# ovlp_count                                                  6920
# ovlp_encyclopedia                                       SINE_Alu
# ovlp_encyclopedia_size                               1.17725e+06
# z_random                                                       0
# z_shuffled                                                     0
#
#                                                             2     \
# biosample_name          common myeloid progenitor, CD34-positive
# biosample_type                                      primary cell
# encyclopedia                                              ENCODE
# encyclopedia_size                                          38914
# fisher_left_p                                                NaN
# fisher_oddsratio                                             NaN
# fisher_right_p                                                 1
# fisher_two_p                                                 NaN
# jaccard                                               0.00248551
# min_ovlp                                                    0.15
# ovlp_count                                                  3589
# ovlp_encyclopedia                                       SINE_Alu
# ovlp_encyclopedia_size                               1.17725e+06
# z_random                                                       0
# z_shuffled                                                     0
#
#                                                             3     \
# biosample_name          common myeloid progenitor, CD34-positive
# biosample_type                                      primary cell
# encyclopedia                                              ENCODE
# encyclopedia_size                                          38914
# fisher_left_p                                                NaN
# fisher_oddsratio                                             NaN
# fisher_right_p                                                 1
# fisher_two_p                                                 NaN
# jaccard                                               0.00131454
# min_ovlp                                                     0.2
# ovlp_count                                                  1900
# ovlp_encyclopedia                                       SINE_Alu
# ovlp_encyclopedia_size                               1.17725e+06
# z_random                                                       0
# z_shuffled                                                     0
#
#                                                             4     \
# biosample_name          common myeloid progenitor, CD34-positive
# biosample_type                                      primary cell
# encyclopedia                                              ENCODE
# encyclopedia_size                                          38914
# fisher_left_p                                                NaN
# fisher_oddsratio                                             NaN
# fisher_right_p                                                 1
# fisher_two_p                                                 NaN
# jaccard                                              0.000696875
# min_ovlp                                                    0.25
# ovlp_count                                                  1022
# ovlp_encyclopedia                                       SINE_Alu
# ovlp_encyclopedia_size                               1.17725e+06
# z_random                                                       0
# z_shuffled                                                     0
#
#                                                             5     \
# biosample_name          common myeloid progenitor, CD34-positive
# biosample_type                                      primary cell
# encyclopedia                                              ENCODE
# encyclopedia_size                                          38914
# fisher_left_p                                                NaN
# fisher_oddsratio                                             NaN
# fisher_right_p                                                 1
# fisher_two_p                                                 NaN
# jaccard                                              0.000365505
# min_ovlp                                                     0.3
# ovlp_count                                                   561
# ovlp_encyclopedia                                       SINE_Alu
# ovlp_encyclopedia_size                               1.17725e+06
# z_random                                                       0
# z_shuffled                                                     0
#
#                                                             6     \
# biosample_name          common myeloid progenitor, CD34-positive
# biosample_type                                      primary cell
# encyclopedia                                              ENCODE
# encyclopedia_size                                          38914
# fisher_left_p                                                NaN
# fisher_oddsratio                                             NaN
# fisher_right_p                                                 1
# fisher_two_p                                                 NaN
# jaccard                                              0.000168197
# min_ovlp                                                    0.35
# ovlp_count                                                   291
# ovlp_encyclopedia                                       SINE_Alu
# ovlp_encyclopedia_size                               1.17725e+06
# z_random                                                       0
# z_shuffled                                                     0
#
#                                                             7     \
# biosample_name          common myeloid progenitor, CD34-positive
# biosample_type                                      primary cell
# encyclopedia                                              ENCODE
# encyclopedia_size                                          38914
# fisher_left_p                                                NaN
# fisher_oddsratio                                             NaN
# fisher_right_p                                                 1
# fisher_two_p                                                 NaN
# jaccard                                              7.28687e-05
# min_ovlp                                                     0.4
# ovlp_count                                                   155
# ovlp_encyclopedia                                       SINE_Alu
# ovlp_encyclopedia_size                               1.17725e+06
# z_random                                                       0
# z_shuffled                                                     0
#
#                                                             8     \
# biosample_name          common myeloid progenitor, CD34-positive
# biosample_type                                      primary cell
# encyclopedia                                              ENCODE
# encyclopedia_size                                          38914
# fisher_left_p                                                NaN
# fisher_oddsratio                                             NaN
# fisher_right_p                                                 1
# fisher_two_p                                                 NaN
# jaccard                                              4.64558e-05
# min_ovlp                                                    0.45
# ovlp_count                                                   110
# ovlp_encyclopedia                                       SINE_Alu
# ovlp_encyclopedia_size                               1.17725e+06
# z_random                                                       0
# z_shuffled                                                     0
#
#                                                             9     \
# biosample_name          common myeloid progenitor, CD34-positive
# biosample_type                                      primary cell
# encyclopedia                                              ENCODE
# encyclopedia_size                                          38914
# fisher_left_p                                                NaN
# fisher_oddsratio                                             NaN
# fisher_right_p                                                 1
# fisher_two_p                                                 NaN
# jaccard                                              3.61075e-05
# min_ovlp                                                     0.5
# ovlp_count                                                    89
# ovlp_encyclopedia                                       SINE_Alu
# ovlp_encyclopedia_size                               1.17725e+06
# z_random                                                       0
# z_shuffled                                                     0
#
#                                ...                          1016  \
# biosample_name                 ...           foreskin fibroblast
# biosample_type                 ...                  primary cell
# encyclopedia                   ...                        ENCODE
# encyclopedia_size              ...                         37894
# fisher_left_p                  ...                             0
# fisher_oddsratio               ...                         0.009
# fisher_right_p                 ...                             1
# fisher_two_p                   ...                             0
# jaccard                        ...                   0.000398703
# min_ovlp                       ...                           0.5
# ovlp_count                     ...                           767
# ovlp_encyclopedia              ...                      SHUFFLED
# ovlp_encyclopedia_size         ...                   1.17725e+06
# z_random                       ...                           NaN
# z_shuffled                     ...                           NaN
#
#                                        1017                 1018  \
# biosample_name          foreskin fibroblast  foreskin fibroblast
# biosample_type                 primary cell         primary cell
# encyclopedia                         ENCODE               ENCODE
# encyclopedia_size                     37894                37894
# fisher_left_p                             0                    0
# fisher_oddsratio                      0.008                0.007
# fisher_right_p                            1                    1
# fisher_two_p                              0                    0
# jaccard                         0.000323662          0.000276503
# min_ovlp                               0.55                  0.6
# ovlp_count                              677                  615
# ovlp_encyclopedia                  SHUFFLED             SHUFFLED
# ovlp_encyclopedia_size          1.17725e+06          1.17725e+06
# z_random                                NaN                  NaN
# z_shuffled                              NaN                  NaN
#
#                                        1019                 1020  \
# biosample_name          foreskin fibroblast  foreskin fibroblast
# biosample_type                 primary cell         primary cell
# encyclopedia                         ENCODE               ENCODE
# encyclopedia_size                     37894                37894
# fisher_left_p                             0                    0
# fisher_oddsratio                      0.006                0.006
# fisher_right_p                            1                    1
# fisher_two_p                              0                    0
# jaccard                         0.000252485          0.000226326
# min_ovlp                               0.65                  0.7
# ovlp_count                              567                  513
# ovlp_encyclopedia                  SHUFFLED             SHUFFLED
# ovlp_encyclopedia_size          1.17725e+06          1.17725e+06
# z_random                                NaN                  NaN
# z_shuffled                              NaN                  NaN
#
#                                        1021                 1022  \
# biosample_name          foreskin fibroblast  foreskin fibroblast
# biosample_type                 primary cell         primary cell
# encyclopedia                         ENCODE               ENCODE
# encyclopedia_size                     37894                37894
# fisher_left_p                             0                    0
# fisher_oddsratio                      0.005                0.005
# fisher_right_p                            1                    1
# fisher_two_p                              0                    0
# jaccard                         0.000208374          0.000186499
# min_ovlp                               0.75                  0.8
# ovlp_count                              472                  429
# ovlp_encyclopedia                  SHUFFLED             SHUFFLED
# ovlp_encyclopedia_size          1.17725e+06          1.17725e+06
# z_random                                NaN                  NaN
# z_shuffled                              NaN                  NaN
#
#                                        1023                 1024  \
# biosample_name          foreskin fibroblast  foreskin fibroblast
# biosample_type                 primary cell         primary cell
# encyclopedia                         ENCODE               ENCODE
# encyclopedia_size                     37894                37894
# fisher_left_p                             0                    0
# fisher_oddsratio                      0.004                0.004
# fisher_right_p                            1                    1
# fisher_two_p                              0                    0
# jaccard                         0.000166509           0.00014832
# min_ovlp                               0.85                  0.9
# ovlp_count                              381                  343
# ovlp_encyclopedia                  SHUFFLED             SHUFFLED
# ovlp_encyclopedia_size          1.17725e+06          1.17725e+06
# z_random                                NaN                  NaN
# z_shuffled                              NaN                  NaN
#
#                                        1025
# biosample_name          foreskin fibroblast
# biosample_type                 primary cell
# encyclopedia                         ENCODE
# encyclopedia_size                     37894
# fisher_left_p                             0
# fisher_oddsratio                      0.003
# fisher_right_p                            1
# fisher_two_p                              0
# jaccard                         0.000134035
# min_ovlp                               0.95
# ovlp_count                              305
# ovlp_encyclopedia                  SHUFFLED
# ovlp_encyclopedia_size          1.17725e+06
# z_random                                NaN
# z_shuffled                              NaN
#
# [15 rows x 1026 columns]

# %%
stem_ovlp_df['biosample_name'].unique()
# Out:
# array(['common myeloid progenitor, CD34-positive', 'B cell',
#        'skeletal muscle myoblast', 'fibroblast of dermis', 'keratinocyte',
#        'fibroblast of lung', 'foreskin melanocyte',
#        'CD14-positive monocyte', 'mammary epithelial cell', 'IMR-90',
#        'endothelial cell of umbilical vein', 'natural killer cell',
#        'astrocyte', 'foreskin fibroblast', 'trophoblast cell', 'T-cell'], dtype=object)

# %%
import seaborn as sns
# %matplotlib inline

# %%
sns.set(style="whitegrid")
sns.set_context("poster", font_scale=0.7, rc={"lines.linewidth": 1})

g = sns.FacetGrid(stem_ovlp_df, col="biosample_name", hue="ovlp_encyclopedia", col_wrap=2, size=7)
g.map(sns.pointplot, "min_ovlp", "jaccard", capsize=.2, size=6, aspect=1)
g.add_legend();

# %%
sns.set(style="whitegrid")
sns.set_context("poster", font_scale=0.8, rc={"lines.linewidth": 0.8})

g = sns.FacetGrid(stem_ovlp_df, col="biosample_name", hue="ovlp_encyclopedia", col_wrap=2, size=7)
g.map(sns.pointplot, "min_ovlp", "fisher_right_p", capsize=.2, size=6, aspect=1)
g.add_legend();
