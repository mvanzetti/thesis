# %%
import pandas as pd
from pybedtools import BedTool

def compute_ovlp_len( row):
    if row['SE_name'] == '.':
        return 0
    value = min(row['end'], row['SE_end']) - max(row['start'], row['SE_start'])
    return value

def compute_ovlp_pct( row):
    size = abs(row['end'] - row['start'])
    value = row['SE_ovlp_len'] / size * 100.0
    return value


assembly='hg19'
method='DNase_H3K27ac'
min_overlap=0.1

staging_path = "/Users/manuel/development/thesis/staging"
overlap_path = "/Users/manuel/development/thesis/overlap"
encode_file_name = "filtered_"

if assembly:
    encode_file_name += assembly
if method:
    encode_file_name += method

encode_file_path = staging_path + "/ENCODE/filtered/" + encode_file_name + ".csv"
dbsuper_file_path = staging_path + "/dbSUPER/adrenal_gland_dbSUPER_sample_full.csv"
encode_bed_file_path = staging_path + "/dbSUPER/adrenal_gland_ENCODE_sample.bed"
dbsuper_bed_filepath = staging_path + "/dbSUPER/adrenal_gland_dbSUPER_sample.bed"

encode_bed = BedTool(encode_bed_file_path)
dbsuper_bed = BedTool(dbsuper_bed_filepath)

print("ENCODE bed file:", encode_bed_file_path)
print("dbSUPER bed file:", dbsuper_bed_filepath)
print("Starting overlap...")

# full_dbSUPER_intersect_ENCODE = dbsuper_bed.intersect(encode_bed, wa=True, f=0.1)
encode_intersect_dbsuper = encode_bed.intersect(dbsuper_bed, loj=True, f=min_overlap)

# print(len(full_dbSUPER_intersect_ENCODE), "dbSUPER.intersect(ENCODE) results")
print(len(encode_intersect_dbsuper), "ENCODE.intersect(dbSUPER) results")

overlap_column_names = ['chrom', 'start', 'end', 'name', 'score', 'strand', 'thickStart', 'thickEnd', 'itemRgb',
                        'SE_chrom', \
                        'SE_start', 'SE_end', 'SE_name', 'SE_score']
overlap_df = encode_intersect_dbsuper.to_dataframe(names=overlap_column_names)

print("dbSUPER details file:", dbsuper_file_path)
full_dbsuper_details_df = pd.read_csv(dbsuper_file_path, sep=',')

print("Merging details from dbSUPER...")
overlap_full_detail_df = overlap_df.merge(
    full_dbsuper_details_df[['ID', 'Size', 'Associated Gene', 'Method', 'Rank', 'Cell/Tissue']],
    how='left', left_on='SE_name', right_on='ID')

overlap_full_detail_df = overlap_full_detail_df.drop('thickStart', axis=1)
overlap_full_detail_df = overlap_full_detail_df.drop('thickEnd', axis=1)
overlap_full_detail_df = overlap_full_detail_df.drop('itemRgb', axis=1)
overlap_full_detail_df = overlap_full_detail_df.drop('ID', axis=1)
overlap_full_detail_df = overlap_full_detail_df.drop('Rank', axis=1)

overlap_full_detail_df.columns = ['chrom', 'start', 'end', 'name', 'score', 'strand', 'SE_chrom',
                                  'SE_start', 'SE_end', 'SE_name', 'SE_score', 'SE_size',
                                  'SE_associated_gene', 'SE_method', 'SE_biosample']

overlap_full_detail_df['SE_ovlp_len'] = overlap_full_detail_df.apply(lambda row: compute_ovlp_len(row),
                                                                     axis=1)
overlap_full_detail_df['SE_ovlp_pct'] = overlap_full_detail_df.apply(lambda row: compute_ovlp_pct(row),
                                                                     axis=1)

overlap_full_detail_df['SE_associated_gene'].fillna('.', inplace=True)
overlap_full_detail_df['SE_method'].fillna('.', inplace=True)
overlap_full_detail_df['SE_biosample'].fillna('.', inplace=True)
#overlap_full_detail_df['SE_size'].fillna('-1', inplace=True)
# Out:
# ENCODE bed file: /Users/manuel/development/thesis/staging/dbSUPER/adrenal_gland_ENCODE_sample.bed
# dbSUPER bed file: /Users/manuel/development/thesis/staging/dbSUPER/adrenal_gland_dbSUPER_sample.bed
# Starting overlap...
# 38634 ENCODE.intersect(dbSUPER) results
# dbSUPER details file: /Users/manuel/development/thesis/staging/dbSUPER/adrenal_gland_dbSUPER_sample_full.csv
# Merging details from dbSUPER...

# %%
overlap_full_detail_df['name'] = 'ENCODE.3.ENCFF778PVS.0'
overlap_full_detail_df.T
# Out:
#                                      0                       1      \
# chrom                                chr13                   chr14
# start                             34114318                35800256
# end                               34118911                35812312
# name                ENCODE.3.ENCFF778PVS.0  ENCODE.3.ENCFF778PVS.0
# score                                    1                       1
# strand                                   .                       .
# SE_chrom                                 .                   chr14
# SE_start                                -1                35800648
# SE_end                                  -1                35813368
# SE_name                                  .                SE_01165
# SE_score                                -1                     313
# SE_size                                NaN                   12720
# SE_associated_gene                       .                   PSMA6
# SE_method                                .                 H3K27ac
# SE_biosample                             .           Adrenal Gland
# SE_ovlp_len                              0                   11664
# SE_ovlp_pct                              0                 96.7485
#
#                                      2                       3      \
# chrom                                chr16                   chr14
# start                             22200146                62025090
# end                               22205387                62033524
# name                ENCODE.3.ENCFF778PVS.0  ENCODE.3.ENCFF778PVS.0
# score                                    1                       1
# strand                                   .                       .
# SE_chrom                                 .                   chr14
# SE_start                                -1                61977862
# SE_end                                  -1                62062455
# SE_name                                  .                SE_00951
# SE_score                                -1                      99
# SE_size                                NaN                   84593
# SE_associated_gene                       .                   HIF1A
# SE_method                                .                 H3K27ac
# SE_biosample                             .           Adrenal Gland
# SE_ovlp_len                              0                    8434
# SE_ovlp_pct                              0                     100
#
#                                      4                       5      \
# chrom                                chr12                   chr19
# start                              8178209                18413303
# end                                8180468                18418380
# name                ENCODE.3.ENCFF778PVS.0  ENCODE.3.ENCFF778PVS.0
# score                                    1                       1
# strand                                   .                       .
# SE_chrom                                 .                       .
# SE_start                                -1                      -1
# SE_end                                  -1                      -1
# SE_name                                  .                       .
# SE_score                                -1                      -1
# SE_size                                NaN                     NaN
# SE_associated_gene                       .                       .
# SE_method                                .                       .
# SE_biosample                             .                       .
# SE_ovlp_len                              0                       0
# SE_ovlp_pct                              0                       0
#
#                                      6                       7      \
# chrom                                chr17                   chr19
# start                             41436643                 2057975
# end                               41439942                 2063141
# name                ENCODE.3.ENCFF778PVS.0  ENCODE.3.ENCFF778PVS.0
# score                                    1                       1
# strand                                   .                       .
# SE_chrom                                 .                   chr19
# SE_start                                -1                 2031672
# SE_end                                  -1                 2094175
# SE_name                                  .                SE_00877
# SE_score                                -1                      25
# SE_size                                NaN                   62503
# SE_associated_gene                       .                   MKNK2
# SE_method                                .                 H3K27ac
# SE_biosample                             .           Adrenal Gland
# SE_ovlp_len                              0                    5166
# SE_ovlp_pct                              0                     100
#
#                                      8                       9      \
# chrom                                 chr7                   chr19
# start                            130008428                39891316
# end                              130015073                39895380
# name                ENCODE.3.ENCFF778PVS.0  ENCODE.3.ENCFF778PVS.0
# score                                    1                       1
# strand                                   .                       .
# SE_chrom                                 .                   chr19
# SE_start                                -1                39887759
# SE_end                                  -1                39902523
# SE_name                                  .                SE_01016
# SE_score                                -1                     164
# SE_size                                NaN                   14764
# SE_associated_gene                       .                   ZFP36
# SE_method                                .                 H3K27ac
# SE_biosample                             .           Adrenal Gland
# SE_ovlp_len                              0                    4064
# SE_ovlp_pct                              0                     100
#
#                              ...                             38624  \
# chrom                        ...                             chr19
# start                        ...                          46880463
# end                          ...                          46882005
# name                         ...            ENCODE.3.ENCFF778PVS.0
# score                        ...                                 1
# strand                       ...                                 .
# SE_chrom                     ...                                 .
# SE_start                     ...                                -1
# SE_end                       ...                                -1
# SE_name                      ...                                 .
# SE_score                     ...                                -1
# SE_size                      ...                               NaN
# SE_associated_gene           ...                                 .
# SE_method                    ...                                 .
# SE_biosample                 ...                                 .
# SE_ovlp_len                  ...                                 0
# SE_ovlp_pct                  ...                                 0
#
#                                      38625                   38626  \
# chrom                                chr19                   chr17
# start                             45260914                52847987
# end                               45261457                52848805
# name                ENCODE.3.ENCFF778PVS.0  ENCODE.3.ENCFF778PVS.0
# score                                    1                       1
# strand                                   .                       .
# SE_chrom                             chr19                       .
# SE_start                          45240079                      -1
# SE_end                            45263101                      -1
# SE_name                           SE_01042                       .
# SE_score                               190                      -1
# SE_size                              23022                     NaN
# SE_associated_gene                    BCL3                       .
# SE_method                          H3K27ac                       .
# SE_biosample                 Adrenal Gland                       .
# SE_ovlp_len                            543                       0
# SE_ovlp_pct                            100                       0
#
#                                      38627                   38628  \
# chrom                                chr19                   chr12
# start                             11465980                54820681
# end                               11466130                54823625
# name                ENCODE.3.ENCFF778PVS.0  ENCODE.3.ENCFF778PVS.0
# score                                    1                       1
# strand                                   .                       .
# SE_chrom                                 .                       .
# SE_start                                -1                      -1
# SE_end                                  -1                      -1
# SE_name                                  .                       .
# SE_score                                -1                      -1
# SE_size                                NaN                     NaN
# SE_associated_gene                       .                       .
# SE_method                                .                       .
# SE_biosample                             .                       .
# SE_ovlp_len                              0                       0
# SE_ovlp_pct                              0                       0
#
#                                      38629                   38630  \
# chrom                                 chr5                   chr16
# start                            121647840                67193280
# end                              121647990                67194085
# name                ENCODE.3.ENCFF778PVS.0  ENCODE.3.ENCFF778PVS.0
# score                                    1                       1
# strand                                   .                       .
# SE_chrom                                 .                       .
# SE_start                                -1                      -1
# SE_end                                  -1                      -1
# SE_name                                  .                       .
# SE_score                                -1                      -1
# SE_size                                NaN                     NaN
# SE_associated_gene                       .                       .
# SE_method                                .                       .
# SE_biosample                             .                       .
# SE_ovlp_len                              0                       0
# SE_ovlp_pct                              0                       0
#
#                                      38631                   38632  \
# chrom                                chr11                   chr18
# start                             44117140                24127860
# end                               44117290                24128010
# name                ENCODE.3.ENCFF778PVS.0  ENCODE.3.ENCFF778PVS.0
# score                                    1                       1
# strand                                   .                       .
# SE_chrom                                 .                       .
# SE_start                                -1                      -1
# SE_end                                  -1                      -1
# SE_name                                  .                       .
# SE_score                                -1                      -1
# SE_size                                NaN                     NaN
# SE_associated_gene                       .                       .
# SE_method                                .                       .
# SE_biosample                             .                       .
# SE_ovlp_len                              0                       0
# SE_ovlp_pct                              0                       0
#
#                                      38633
# chrom                                chr16
# start                             11762160
# end                               11762310
# name                ENCODE.3.ENCFF778PVS.0
# score                                    1
# strand                                   .
# SE_chrom                                 .
# SE_start                                -1
# SE_end                                  -1
# SE_name                                  .
# SE_score                                -1
# SE_size                                NaN
# SE_associated_gene                       .
# SE_method                                .
# SE_biosample                             .
# SE_ovlp_len                              0
# SE_ovlp_pct                              0
#
# [17 rows x 38634 columns]

# %%
print("ENCODE details file:", encode_file_path)
encode_details_df = pd.read_csv(encode_file_path, sep='\t')
# Out:
# ENCODE details file: /Users/manuel/development/thesis/staging/ENCODE/filtered/filtered_hg19DNase_H3K27ac.csv

# %%
encode_details_df.T
# Out:
#                                                                 0        \
# chrom                                                              chr3
# start                                                         152855118
# end                                                           152861069
# name                                                Distal-Prediction-1
# score                                                                 1
# strand                                                                .
# candidate_id                                     ENCODE.3.ENCFF778PVS.0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                           ['mammary gland']
# organism                                              /organisms/human/
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                 1        \
# chrom                                                              chr1
# start                                                         214611302
# end                                                           214622352
# name                                                Distal-Prediction-2
# score                                                                 1
# strand                                                                .
# candidate_id                                     ENCODE.3.ENCFF778PVS.1
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                           ['mammary gland']
# organism                                              /organisms/human/
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                 2        \
# chrom                                                             chr15
# start                                                         101260386
# end                                                           101269291
# name                                                Distal-Prediction-3
# score                                                                 1
# strand                                                                .
# candidate_id                                     ENCODE.3.ENCFF778PVS.2
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                           ['mammary gland']
# organism                                              /organisms/human/
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                 3        \
# chrom                                                              chr5
# start                                                          52654619
# end                                                            52660930
# name                                                Distal-Prediction-4
# score                                                                 1
# strand                                                                .
# candidate_id                                     ENCODE.3.ENCFF778PVS.3
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                           ['mammary gland']
# organism                                              /organisms/human/
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                 4        \
# chrom                                                             chr11
# start                                                           9586536
# end                                                             9592486
# name                                                Distal-Prediction-5
# score                                                                 1
# strand                                                                .
# candidate_id                                     ENCODE.3.ENCFF778PVS.4
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                           ['mammary gland']
# organism                                              /organisms/human/
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                 5        \
# chrom                                                              chr5
# start                                                         148864272
# end                                                           148869801
# name                                                Distal-Prediction-6
# score                                                                 1
# strand                                                                .
# candidate_id                                     ENCODE.3.ENCFF778PVS.5
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                           ['mammary gland']
# organism                                              /organisms/human/
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                 6        \
# chrom                                                             chr10
# start                                                           3892558
# end                                                             3895911
# name                                                Distal-Prediction-7
# score                                                                 1
# strand                                                                .
# candidate_id                                     ENCODE.3.ENCFF778PVS.6
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                           ['mammary gland']
# organism                                              /organisms/human/
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                 7        \
# chrom                                                             chr10
# start                                                           5624645
# end                                                             5628826
# name                                                Distal-Prediction-8
# score                                                                 1
# strand                                                                .
# candidate_id                                     ENCODE.3.ENCFF778PVS.7
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                           ['mammary gland']
# organism                                              /organisms/human/
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                 8        \
# chrom                                                              chr3
# start                                                           5062817
# end                                                             5068862
# name                                                Distal-Prediction-9
# score                                                                 1
# strand                                                                .
# candidate_id                                     ENCODE.3.ENCFF778PVS.8
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                           ['mammary gland']
# organism                                              /organisms/human/
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                 9        \
# chrom                                                              chr8
# start                                                         126230865
# end                                                           126234434
# name                                               Distal-Prediction-10
# score                                                                 1
# strand                                                                .
# candidate_id                                     ENCODE.3.ENCFF778PVS.9
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                           ['mammary gland']
# organism                                              /organisms/human/
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                             ...                          \
# chrom                                       ...
# start                                       ...
# end                                         ...
# name                                        ...
# score                                       ...
# strand                                      ...
# candidate_id                                ...
# assembly                                    ...
# biosample_term_id                           ...
# biosample_term_name                         ...
# biosample_type                              ...
# description                                 ...
# developmental_slims                         ...
# encyclopedia                                ...
# encyclopedia_version                        ...
# month_released                              ...
# organ_slims                                 ...
# organism                                    ...
# system_slims                                ...
# method                                      ...
#
#                                                                 1785570  \
# chrom                                                             chr16
# start                                                          58528640
# end                                                            58529655
# name                                          Proximal-Prediction-14000
# score                                                                 1
# strand                                                                .
# candidate_id                                 ENCODE.3.ENCFF026HMJ.33999
# assembly                                                           hg19
# biosample_term_id                                            CL:0002372
# biosample_term_name                                             myotube
# biosample_type                            in vitro differentiated cells
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['muscle organ']
# organism                                              /organisms/human/
# system_slims                                    ['musculature of body']
# method                                                    DNase_H3K27ac
#
#                                                                 1785571  \
# chrom                                                              chr1
# start                                                          60138160
# end                                                            60139325
# name                                          Proximal-Prediction-14001
# score                                                                 1
# strand                                                                .
# candidate_id                                 ENCODE.3.ENCFF026HMJ.34000
# assembly                                                           hg19
# biosample_term_id                                            CL:0002372
# biosample_term_name                                             myotube
# biosample_type                            in vitro differentiated cells
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['muscle organ']
# organism                                              /organisms/human/
# system_slims                                    ['musculature of body']
# method                                                    DNase_H3K27ac
#
#                                                                 1785572  \
# chrom                                                              chr6
# start                                                         105771787
# end                                                           105773337
# name                                          Proximal-Prediction-14002
# score                                                                 1
# strand                                                                .
# candidate_id                                 ENCODE.3.ENCFF026HMJ.34001
# assembly                                                           hg19
# biosample_term_id                                            CL:0002372
# biosample_term_name                                             myotube
# biosample_type                            in vitro differentiated cells
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['muscle organ']
# organism                                              /organisms/human/
# system_slims                                    ['musculature of body']
# method                                                    DNase_H3K27ac
#
#                                                                 1785573  \
# chrom                                                             chr19
# start                                                           8428130
# end                                                             8429430
# name                                          Proximal-Prediction-14003
# score                                                                 1
# strand                                                                .
# candidate_id                                 ENCODE.3.ENCFF026HMJ.34002
# assembly                                                           hg19
# biosample_term_id                                            CL:0002372
# biosample_term_name                                             myotube
# biosample_type                            in vitro differentiated cells
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['muscle organ']
# organism                                              /organisms/human/
# system_slims                                    ['musculature of body']
# method                                                    DNase_H3K27ac
#
#                                                                 1785574  \
# chrom                                                              chr7
# start                                                          24613000
# end                                                            24613150
# name                                          Proximal-Prediction-14004
# score                                                                 1
# strand                                                                .
# candidate_id                                 ENCODE.3.ENCFF026HMJ.34003
# assembly                                                           hg19
# biosample_term_id                                            CL:0002372
# biosample_term_name                                             myotube
# biosample_type                            in vitro differentiated cells
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['muscle organ']
# organism                                              /organisms/human/
# system_slims                                    ['musculature of body']
# method                                                    DNase_H3K27ac
#
#                                                                 1785575  \
# chrom                                                             chr18
# start                                                          20807015
# end                                                            20808529
# name                                          Proximal-Prediction-14005
# score                                                                 1
# strand                                                                .
# candidate_id                                 ENCODE.3.ENCFF026HMJ.34004
# assembly                                                           hg19
# biosample_term_id                                            CL:0002372
# biosample_term_name                                             myotube
# biosample_type                            in vitro differentiated cells
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['muscle organ']
# organism                                              /organisms/human/
# system_slims                                    ['musculature of body']
# method                                                    DNase_H3K27ac
#
#                                                                 1785576  \
# chrom                                                              chr1
# start                                                         150485494
# end                                                           150486475
# name                                          Proximal-Prediction-14006
# score                                                                 1
# strand                                                                .
# candidate_id                                 ENCODE.3.ENCFF026HMJ.34005
# assembly                                                           hg19
# biosample_term_id                                            CL:0002372
# biosample_term_name                                             myotube
# biosample_type                            in vitro differentiated cells
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['muscle organ']
# organism                                              /organisms/human/
# system_slims                                    ['musculature of body']
# method                                                    DNase_H3K27ac
#
#                                                                 1785577  \
# chrom                                                              chr5
# start                                                         178450920
# end                                                           178451070
# name                                          Proximal-Prediction-14007
# score                                                                 1
# strand                                                                .
# candidate_id                                 ENCODE.3.ENCFF026HMJ.34006
# assembly                                                           hg19
# biosample_term_id                                            CL:0002372
# biosample_term_name                                             myotube
# biosample_type                            in vitro differentiated cells
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['muscle organ']
# organism                                              /organisms/human/
# system_slims                                    ['musculature of body']
# method                                                    DNase_H3K27ac
#
#                                                                 1785578  \
# chrom                                                              chr6
# start                                                         155442359
# end                                                           155443585
# name                                          Proximal-Prediction-14008
# score                                                                 1
# strand                                                                .
# candidate_id                                 ENCODE.3.ENCFF026HMJ.34007
# assembly                                                           hg19
# biosample_term_id                                            CL:0002372
# biosample_term_name                                             myotube
# biosample_type                            in vitro differentiated cells
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['muscle organ']
# organism                                              /organisms/human/
# system_slims                                    ['musculature of body']
# method                                                    DNase_H3K27ac
#
#                                                                 1785579
# chrom                                                             chr17
# start                                                          37309960
# end                                                            37310110
# name                                          Proximal-Prediction-14009
# score                                                                 1
# strand                                                                .
# candidate_id                                 ENCODE.3.ENCFF026HMJ.34008
# assembly                                                           hg19
# biosample_term_id                                            CL:0002372
# biosample_term_name                                             myotube
# biosample_type                            in vitro differentiated cells
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['mesoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# month_released                                               June, 2016
# organ_slims                                            ['muscle organ']
# organism                                              /organisms/human/
# system_slims                                    ['musculature of body']
# method                                                    DNase_H3K27ac
#
# [20 rows x 1785580 columns]

# %%
print("Merging details from ENCODE...")
overlap_full_detail_encode_df = overlap_full_detail_df.merge(
    encode_details_df[['candidate_id', 'assembly', 'biosample_term_id', 'biosample_term_name', 'biosample_type',
                       'description', 'developmental_slims', 'encyclopedia', 'encyclopedia_version',
                       'organ_slims', 'system_slims', 'method']],
    how='left', left_on='name', right_on='candidate_id'
)
# Out:
# Merging details from ENCODE...

# %%
overlap_full_detail_encode_df.T
# Out:
#                                                                   0      \
# chrom                                                             chr13
# start                                                          34114318
# end                                                            34118911
# name                                             ENCODE.3.ENCFF778PVS.0
# score                                                                 1
# strand                                                                .
# SE_chrom                                                              .
# SE_start                                                             -1
# SE_end                                                               -1
# SE_name                                                               .
# SE_score                                                             -1
# SE_size                                                             NaN
# SE_associated_gene                                                    .
# SE_method                                                             .
# SE_biosample                                                          .
# SE_ovlp_len                                                           0
# SE_ovlp_pct                                                           0
# candidate_id                                     ENCODE.3.ENCFF778PVS.0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# organ_slims                                           ['mammary gland']
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                   1      \
# chrom                                                             chr14
# start                                                          35800256
# end                                                            35812312
# name                                             ENCODE.3.ENCFF778PVS.0
# score                                                                 1
# strand                                                                .
# SE_chrom                                                          chr14
# SE_start                                                       35800648
# SE_end                                                         35813368
# SE_name                                                        SE_01165
# SE_score                                                            313
# SE_size                                                           12720
# SE_associated_gene                                                PSMA6
# SE_method                                                       H3K27ac
# SE_biosample                                              Adrenal Gland
# SE_ovlp_len                                                       11664
# SE_ovlp_pct                                                     96.7485
# candidate_id                                     ENCODE.3.ENCFF778PVS.0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# organ_slims                                           ['mammary gland']
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                   2      \
# chrom                                                             chr16
# start                                                          22200146
# end                                                            22205387
# name                                             ENCODE.3.ENCFF778PVS.0
# score                                                                 1
# strand                                                                .
# SE_chrom                                                              .
# SE_start                                                             -1
# SE_end                                                               -1
# SE_name                                                               .
# SE_score                                                             -1
# SE_size                                                             NaN
# SE_associated_gene                                                    .
# SE_method                                                             .
# SE_biosample                                                          .
# SE_ovlp_len                                                           0
# SE_ovlp_pct                                                           0
# candidate_id                                     ENCODE.3.ENCFF778PVS.0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# organ_slims                                           ['mammary gland']
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                   3      \
# chrom                                                             chr14
# start                                                          62025090
# end                                                            62033524
# name                                             ENCODE.3.ENCFF778PVS.0
# score                                                                 1
# strand                                                                .
# SE_chrom                                                          chr14
# SE_start                                                       61977862
# SE_end                                                         62062455
# SE_name                                                        SE_00951
# SE_score                                                             99
# SE_size                                                           84593
# SE_associated_gene                                                HIF1A
# SE_method                                                       H3K27ac
# SE_biosample                                              Adrenal Gland
# SE_ovlp_len                                                        8434
# SE_ovlp_pct                                                         100
# candidate_id                                     ENCODE.3.ENCFF778PVS.0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# organ_slims                                           ['mammary gland']
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                   4      \
# chrom                                                             chr12
# start                                                           8178209
# end                                                             8180468
# name                                             ENCODE.3.ENCFF778PVS.0
# score                                                                 1
# strand                                                                .
# SE_chrom                                                              .
# SE_start                                                             -1
# SE_end                                                               -1
# SE_name                                                               .
# SE_score                                                             -1
# SE_size                                                             NaN
# SE_associated_gene                                                    .
# SE_method                                                             .
# SE_biosample                                                          .
# SE_ovlp_len                                                           0
# SE_ovlp_pct                                                           0
# candidate_id                                     ENCODE.3.ENCFF778PVS.0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# organ_slims                                           ['mammary gland']
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                   5      \
# chrom                                                             chr19
# start                                                          18413303
# end                                                            18418380
# name                                             ENCODE.3.ENCFF778PVS.0
# score                                                                 1
# strand                                                                .
# SE_chrom                                                              .
# SE_start                                                             -1
# SE_end                                                               -1
# SE_name                                                               .
# SE_score                                                             -1
# SE_size                                                             NaN
# SE_associated_gene                                                    .
# SE_method                                                             .
# SE_biosample                                                          .
# SE_ovlp_len                                                           0
# SE_ovlp_pct                                                           0
# candidate_id                                     ENCODE.3.ENCFF778PVS.0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# organ_slims                                           ['mammary gland']
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                   6      \
# chrom                                                             chr17
# start                                                          41436643
# end                                                            41439942
# name                                             ENCODE.3.ENCFF778PVS.0
# score                                                                 1
# strand                                                                .
# SE_chrom                                                              .
# SE_start                                                             -1
# SE_end                                                               -1
# SE_name                                                               .
# SE_score                                                             -1
# SE_size                                                             NaN
# SE_associated_gene                                                    .
# SE_method                                                             .
# SE_biosample                                                          .
# SE_ovlp_len                                                           0
# SE_ovlp_pct                                                           0
# candidate_id                                     ENCODE.3.ENCFF778PVS.0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# organ_slims                                           ['mammary gland']
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                   7      \
# chrom                                                             chr19
# start                                                           2057975
# end                                                             2063141
# name                                             ENCODE.3.ENCFF778PVS.0
# score                                                                 1
# strand                                                                .
# SE_chrom                                                          chr19
# SE_start                                                        2031672
# SE_end                                                          2094175
# SE_name                                                        SE_00877
# SE_score                                                             25
# SE_size                                                           62503
# SE_associated_gene                                                MKNK2
# SE_method                                                       H3K27ac
# SE_biosample                                              Adrenal Gland
# SE_ovlp_len                                                        5166
# SE_ovlp_pct                                                         100
# candidate_id                                     ENCODE.3.ENCFF778PVS.0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# organ_slims                                           ['mammary gland']
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                   8      \
# chrom                                                              chr7
# start                                                         130008428
# end                                                           130015073
# name                                             ENCODE.3.ENCFF778PVS.0
# score                                                                 1
# strand                                                                .
# SE_chrom                                                              .
# SE_start                                                             -1
# SE_end                                                               -1
# SE_name                                                               .
# SE_score                                                             -1
# SE_size                                                             NaN
# SE_associated_gene                                                    .
# SE_method                                                             .
# SE_biosample                                                          .
# SE_ovlp_len                                                           0
# SE_ovlp_pct                                                           0
# candidate_id                                     ENCODE.3.ENCFF778PVS.0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# organ_slims                                           ['mammary gland']
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                   9      \
# chrom                                                             chr19
# start                                                          39891316
# end                                                            39895380
# name                                             ENCODE.3.ENCFF778PVS.0
# score                                                                 1
# strand                                                                .
# SE_chrom                                                          chr19
# SE_start                                                       39887759
# SE_end                                                         39902523
# SE_name                                                        SE_01016
# SE_score                                                            164
# SE_size                                                           14764
# SE_associated_gene                                                ZFP36
# SE_method                                                       H3K27ac
# SE_biosample                                              Adrenal Gland
# SE_ovlp_len                                                        4064
# SE_ovlp_pct                                                         100
# candidate_id                                     ENCODE.3.ENCFF778PVS.0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# organ_slims                                           ['mammary gland']
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                             ...                          \
# chrom                                       ...
# start                                       ...
# end                                         ...
# name                                        ...
# score                                       ...
# strand                                      ...
# SE_chrom                                    ...
# SE_start                                    ...
# SE_end                                      ...
# SE_name                                     ...
# SE_score                                    ...
# SE_size                                     ...
# SE_associated_gene                          ...
# SE_method                                   ...
# SE_biosample                                ...
# SE_ovlp_len                                 ...
# SE_ovlp_pct                                 ...
# candidate_id                                ...
# assembly                                    ...
# biosample_term_id                           ...
# biosample_term_name                         ...
# biosample_type                              ...
# description                                 ...
# developmental_slims                         ...
# encyclopedia                                ...
# encyclopedia_version                        ...
# organ_slims                                 ...
# system_slims                                ...
# method                                      ...
#
#                                                                   38624  \
# chrom                                                             chr19
# start                                                          46880463
# end                                                            46882005
# name                                             ENCODE.3.ENCFF778PVS.0
# score                                                                 1
# strand                                                                .
# SE_chrom                                                              .
# SE_start                                                             -1
# SE_end                                                               -1
# SE_name                                                               .
# SE_score                                                             -1
# SE_size                                                             NaN
# SE_associated_gene                                                    .
# SE_method                                                             .
# SE_biosample                                                          .
# SE_ovlp_len                                                           0
# SE_ovlp_pct                                                           0
# candidate_id                                     ENCODE.3.ENCFF778PVS.0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# organ_slims                                           ['mammary gland']
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                   38625  \
# chrom                                                             chr19
# start                                                          45260914
# end                                                            45261457
# name                                             ENCODE.3.ENCFF778PVS.0
# score                                                                 1
# strand                                                                .
# SE_chrom                                                          chr19
# SE_start                                                       45240079
# SE_end                                                         45263101
# SE_name                                                        SE_01042
# SE_score                                                            190
# SE_size                                                           23022
# SE_associated_gene                                                 BCL3
# SE_method                                                       H3K27ac
# SE_biosample                                              Adrenal Gland
# SE_ovlp_len                                                         543
# SE_ovlp_pct                                                         100
# candidate_id                                     ENCODE.3.ENCFF778PVS.0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# organ_slims                                           ['mammary gland']
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                   38626  \
# chrom                                                             chr17
# start                                                          52847987
# end                                                            52848805
# name                                             ENCODE.3.ENCFF778PVS.0
# score                                                                 1
# strand                                                                .
# SE_chrom                                                              .
# SE_start                                                             -1
# SE_end                                                               -1
# SE_name                                                               .
# SE_score                                                             -1
# SE_size                                                             NaN
# SE_associated_gene                                                    .
# SE_method                                                             .
# SE_biosample                                                          .
# SE_ovlp_len                                                           0
# SE_ovlp_pct                                                           0
# candidate_id                                     ENCODE.3.ENCFF778PVS.0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# organ_slims                                           ['mammary gland']
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                   38627  \
# chrom                                                             chr19
# start                                                          11465980
# end                                                            11466130
# name                                             ENCODE.3.ENCFF778PVS.0
# score                                                                 1
# strand                                                                .
# SE_chrom                                                              .
# SE_start                                                             -1
# SE_end                                                               -1
# SE_name                                                               .
# SE_score                                                             -1
# SE_size                                                             NaN
# SE_associated_gene                                                    .
# SE_method                                                             .
# SE_biosample                                                          .
# SE_ovlp_len                                                           0
# SE_ovlp_pct                                                           0
# candidate_id                                     ENCODE.3.ENCFF778PVS.0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# organ_slims                                           ['mammary gland']
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                   38628  \
# chrom                                                             chr12
# start                                                          54820681
# end                                                            54823625
# name                                             ENCODE.3.ENCFF778PVS.0
# score                                                                 1
# strand                                                                .
# SE_chrom                                                              .
# SE_start                                                             -1
# SE_end                                                               -1
# SE_name                                                               .
# SE_score                                                             -1
# SE_size                                                             NaN
# SE_associated_gene                                                    .
# SE_method                                                             .
# SE_biosample                                                          .
# SE_ovlp_len                                                           0
# SE_ovlp_pct                                                           0
# candidate_id                                     ENCODE.3.ENCFF778PVS.0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# organ_slims                                           ['mammary gland']
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                   38629  \
# chrom                                                              chr5
# start                                                         121647840
# end                                                           121647990
# name                                             ENCODE.3.ENCFF778PVS.0
# score                                                                 1
# strand                                                                .
# SE_chrom                                                              .
# SE_start                                                             -1
# SE_end                                                               -1
# SE_name                                                               .
# SE_score                                                             -1
# SE_size                                                             NaN
# SE_associated_gene                                                    .
# SE_method                                                             .
# SE_biosample                                                          .
# SE_ovlp_len                                                           0
# SE_ovlp_pct                                                           0
# candidate_id                                     ENCODE.3.ENCFF778PVS.0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# organ_slims                                           ['mammary gland']
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                   38630  \
# chrom                                                             chr16
# start                                                          67193280
# end                                                            67194085
# name                                             ENCODE.3.ENCFF778PVS.0
# score                                                                 1
# strand                                                                .
# SE_chrom                                                              .
# SE_start                                                             -1
# SE_end                                                               -1
# SE_name                                                               .
# SE_score                                                             -1
# SE_size                                                             NaN
# SE_associated_gene                                                    .
# SE_method                                                             .
# SE_biosample                                                          .
# SE_ovlp_len                                                           0
# SE_ovlp_pct                                                           0
# candidate_id                                     ENCODE.3.ENCFF778PVS.0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# organ_slims                                           ['mammary gland']
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                   38631  \
# chrom                                                             chr11
# start                                                          44117140
# end                                                            44117290
# name                                             ENCODE.3.ENCFF778PVS.0
# score                                                                 1
# strand                                                                .
# SE_chrom                                                              .
# SE_start                                                             -1
# SE_end                                                               -1
# SE_name                                                               .
# SE_score                                                             -1
# SE_size                                                             NaN
# SE_associated_gene                                                    .
# SE_method                                                             .
# SE_biosample                                                          .
# SE_ovlp_len                                                           0
# SE_ovlp_pct                                                           0
# candidate_id                                     ENCODE.3.ENCFF778PVS.0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# organ_slims                                           ['mammary gland']
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                   38632  \
# chrom                                                             chr18
# start                                                          24127860
# end                                                            24128010
# name                                             ENCODE.3.ENCFF778PVS.0
# score                                                                 1
# strand                                                                .
# SE_chrom                                                              .
# SE_start                                                             -1
# SE_end                                                               -1
# SE_name                                                               .
# SE_score                                                             -1
# SE_size                                                             NaN
# SE_associated_gene                                                    .
# SE_method                                                             .
# SE_biosample                                                          .
# SE_ovlp_len                                                           0
# SE_ovlp_pct                                                           0
# candidate_id                                     ENCODE.3.ENCFF778PVS.0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# organ_slims                                           ['mammary gland']
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
#                                                                   38633
# chrom                                                             chr16
# start                                                          11762160
# end                                                            11762310
# name                                             ENCODE.3.ENCFF778PVS.0
# score                                                                 1
# strand                                                                .
# SE_chrom                                                              .
# SE_start                                                             -1
# SE_end                                                               -1
# SE_name                                                               .
# SE_score                                                             -1
# SE_size                                                             NaN
# SE_associated_gene                                                    .
# SE_method                                                             .
# SE_biosample                                                          .
# SE_ovlp_len                                                           0
# SE_ovlp_pct                                                           0
# candidate_id                                     ENCODE.3.ENCFF778PVS.0
# assembly                                                           hg19
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# biosample_type                                             primary cell
# description           Enhancer-like regions using DNase and H3K27ac ...
# developmental_slims                                        ['ectoderm']
# encyclopedia                                                     ENCODE
# encyclopedia_version                                                  3
# organ_slims                                           ['mammary gland']
# system_slims                                    ['integumental system']
# method                                                    DNase_H3K27ac
#
# [29 rows x 38634 columns]

# %%
output_filename = overlap_path + "/" + encode_file_name + "_dbSUPER_overlapped_adrenal_gland.csv"
print("Exporting overlapped file to:", output_filename)
overlap_full_detail_encode_df.to_csv(output_filename, index=None, sep='\t')

print(overlap_full_detail_encode_df.head())
# Out:
# Exporting overlapped file to: /Users/manuel/development/thesis/overlap/filtered_hg19DNase_H3K27ac_dbSUPER_overlapped_adrenal_gland.csv
#    chrom     start       end                    name  score strand SE_chrom  \
# 0  chr13  34114318  34118911  ENCODE.3.ENCFF778PVS.0      1      .        .
# 1  chr14  35800256  35812312  ENCODE.3.ENCFF778PVS.0      1      .    chr14
# 2  chr16  22200146  22205387  ENCODE.3.ENCFF778PVS.0      1      .        .
# 3  chr14  62025090  62033524  ENCODE.3.ENCFF778PVS.0      1      .    chr14
# 4  chr12   8178209   8180468  ENCODE.3.ENCFF778PVS.0      1      .        .
#
#    SE_start    SE_end   SE_name      ...        biosample_term_id  \
# 0        -1        -1         .      ...               CL:0002327
# 1  35800648  35813368  SE_01165      ...               CL:0002327
# 2        -1        -1         .      ...               CL:0002327
# 3  61977862  62062455  SE_00951      ...               CL:0002327
# 4        -1        -1         .      ...               CL:0002327
#
#        biosample_term_name biosample_type  \
# 0  mammary epithelial cell   primary cell
# 1  mammary epithelial cell   primary cell
# 2  mammary epithelial cell   primary cell
# 3  mammary epithelial cell   primary cell
# 4  mammary epithelial cell   primary cell
#
#                                          description developmental_slims  \
# 0  Enhancer-like regions using DNase and H3K27ac ...        ['ectoderm']
# 1  Enhancer-like regions using DNase and H3K27ac ...        ['ectoderm']
# 2  Enhancer-like regions using DNase and H3K27ac ...        ['ectoderm']
# 3  Enhancer-like regions using DNase and H3K27ac ...        ['ectoderm']
# 4  Enhancer-like regions using DNase and H3K27ac ...        ['ectoderm']
#
#    encyclopedia  encyclopedia_version        organ_slims  \
# 0        ENCODE                     3  ['mammary gland']
# 1        ENCODE                     3  ['mammary gland']
# 2        ENCODE                     3  ['mammary gland']
# 3        ENCODE                     3  ['mammary gland']
# 4        ENCODE                     3  ['mammary gland']
#
#               system_slims         method
# 0  ['integumental system']  DNase_H3K27ac
# 1  ['integumental system']  DNase_H3K27ac
# 2  ['integumental system']  DNase_H3K27ac
# 3  ['integumental system']  DNase_H3K27ac
# 4  ['integumental system']  DNase_H3K27ac
#
# [5 rows x 29 columns]

# %%
big_overlap_file = '/Users/manuel/development/thesis/overlap/filtered_hg19DNase_H3K27ac_ROADMAP_overlapped.csv'
import pandas as pd

with open(big_overlap_file) as myfile:
    head = [next(myfile).split('\t') for x in range(1000)]

# %%
head[0]
# Out:
# ['chrom',
#  'start',
#  'end',
#  'name',
#  'score',
#  'strand',
#  'size',
#  'method',
#  'description',
#  'assembly',
#  'biosample_type',
#  'biosample_term_id',
#  'biosample_term_name',
#  'developmental_slims',
#  'system_slims',
#  'organ_slims',
#  'encyclopedia',
#  'RO_chrom',
#  'RO_start',
#  'RO_end',
#  'RO_name',
#  'RO_score',
#  'RO_strand',
#  'RO_size',
#  'RO_method',
#  'RO_biosample_type',
#  'RO_biosample_group',
#  'RO_biosample_name',
#  'RO_biosample_anatomy',
#  'RO_ovlp_len',
#  'RO_ovlp_pct',
#  'RO_encyclopedia\n']

# %%
df = pd.DataFrame(head)
df.columns = head[0]

df['RO_ovlp_pct'].describe()
# Out:
# count                   1000
# unique                    25
# top       49.853306251410515
# freq                      81
# Name: RO_ovlp_pct, dtype: object

# %%
df = pd.DataFrame(head[6:9])
df.columns = head[0]
df.T
# Out:
#                                                                       0  \
# chrom                                                              chr5
# start                                                         148864272
# end                                                           148869801
# name                                             ENCODE.3.ENCFF778PVS.5
# score                                                                 1
# strand                                                                .
# size                                                               5529
# method                                                    DNase_H3K27ac
# description           Enhancer-like regions using DNase and H3K27ac ...
# assembly                                                           hg19
# biosample_type                                             primary cell
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# developmental_slims                                        ['ectoderm']
# system_slims                                    ['integumental system']
# organ_slims                                           ['mammary gland']
# encyclopedia                                                     ENCODE
# RO_chrom                                                           chr5
# RO_start                                                      148865036
# RO_end                                                        148867514
# RO_name                                              ROADMAP.E001.84443
# RO_score                                                              0
# RO_strand                                                             .
# RO_size                                                            2478
# RO_method                                                         DNase
# RO_biosample_type                                        PrimaryCulture
# RO_biosample_group                                                  ESC
# RO_biosample_name                                           ES-I3 Cells
# RO_biosample_anatomy                                                ESC
# RO_ovlp_len                                                        2478
# RO_ovlp_pct                                           44.81823114487249
# RO_encyclopedia\n                                             ROADMAP\n
#
#                                                                       1  \
# chrom                                                              chr5
# start                                                         148864272
# end                                                           148869801
# name                                             ENCODE.3.ENCFF778PVS.5
# score                                                                 1
# strand                                                                .
# size                                                               5529
# method                                                    DNase_H3K27ac
# description           Enhancer-like regions using DNase and H3K27ac ...
# assembly                                                           hg19
# biosample_type                                             primary cell
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# developmental_slims                                        ['ectoderm']
# system_slims                                    ['integumental system']
# organ_slims                                           ['mammary gland']
# encyclopedia                                                     ENCODE
# RO_chrom                                                           chr5
# RO_start                                                      148865036
# RO_end                                                        148867514
# RO_name                                              ROADMAP.E002.28334
# RO_score                                                              0
# RO_strand                                                             .
# RO_size                                                            2478
# RO_method                                                         DNase
# RO_biosample_type                                        PrimaryCulture
# RO_biosample_group                                                  ESC
# RO_biosample_name                                          ES-WA7 Cells
# RO_biosample_anatomy                                                ESC
# RO_ovlp_len                                                        2478
# RO_ovlp_pct                                           44.81823114487249
# RO_encyclopedia\n                                             ROADMAP\n
#
#                                                                       2
# chrom                                                              chr5
# start                                                         148864272
# end                                                           148869801
# name                                             ENCODE.3.ENCFF778PVS.5
# score                                                                 1
# strand                                                                .
# size                                                               5529
# method                                                    DNase_H3K27ac
# description           Enhancer-like regions using DNase and H3K27ac ...
# assembly                                                           hg19
# biosample_type                                             primary cell
# biosample_term_id                                            CL:0002327
# biosample_term_name                             mammary epithelial cell
# developmental_slims                                        ['ectoderm']
# system_slims                                    ['integumental system']
# organ_slims                                           ['mammary gland']
# encyclopedia                                                     ENCODE
# RO_chrom                                                           chr5
# RO_start                                                      148865036
# RO_end                                                        148867514
# RO_name                                              ROADMAP.E005.61152
# RO_score                                                              0
# RO_strand                                                             .
# RO_size                                                            2478
# RO_method                                                         DNase
# RO_biosample_type                                            ESCDerived
# RO_biosample_group                                             ES-deriv
# RO_biosample_name            H1 BMP4 Derived Trophoblast Cultured Cells
# RO_biosample_anatomy                                        ESC_DERIVED
# RO_ovlp_len                                                        2478
# RO_ovlp_pct                                           44.81823114487249
# RO_encyclopedia\n                                             ROADMAP\n

# %%
df.describe()
# Out:
#        chrom      start        end                    name score strand  size  \
# count      3          3          3                       3     3      3     3
# unique     1          1          1                       1     1      1     1
# top     chr5  148864272  148869801  ENCODE.3.ENCFF778PVS.5     1      .  5529
# freq       3          3          3                       3     3      3     3
#
#                method                                        description  \
# count               3                                                  3
# unique              1                                                  1
# top     DNase_H3K27ac  Enhancer-like regions using DNase and H3K27ac ...
# freq                3                                                  3
#
#        assembly        ...        RO_strand RO_size RO_method  \
# count         3        ...                3       3         3
# unique        1        ...                1       1         1
# top        hg19        ...                .    2478     DNase
# freq          3        ...                3       3         3
#
#        RO_biosample_type RO_biosample_group RO_biosample_name  \
# count                  3                  3                 3
# unique                 2                  2                 3
# top       PrimaryCulture                ESC       ES-I3 Cells
# freq                   2                  2                 1
#
#        RO_biosample_anatomy RO_ovlp_len        RO_ovlp_pct RO_encyclopedia\n
# count                     3           3                  3                 3
# unique                    2           1                  1                 1
# top                     ESC        2478  44.81823114487249         ROADMAP\n
# freq                      2           3                  3                 3
#
# [4 rows x 32 columns]

# %%
encode_fantom_df = pd.DataFrame.from_csv('/Users/manuel/development/thesis/overlap/filtered_hg19DNase_H3K27ac_FANTOM_overlapped.csv', sep="\t")

print(len(encode_fantom_df))
# Out:
# 1801781

# %%
encode_fantom_df.query("FA_name != '.'")[0:3].T
# Out:
# chrom                                                            chr10  \
# start                                                          3892558
# end                                                            3895911
# name                                            ENCODE.3.ENCFF778PVS.6
# score                                                                1
# strand                                                               .
# size                                                              3353
# method                                                   DNase_H3K27ac
# description          Enhancer-like regions using DNase and H3K27ac ...
# assembly                                                          hg19
# biosample_type                                            primary cell
# biosample_term_id                                           CL:0002327
# biosample_term_name                            mammary epithelial cell
# developmental_slims                                       ['ectoderm']
# system_slims                                   ['integumental system']
# organ_slims                                          ['mammary gland']
# encyclopedia                                                    ENCODE
# FA_chrom                                                         chr10
# FA_start                                                       3893365
# FA_end                                                         3894190
# FA_name                                       FANTOM.5.PERMISSIVE.3965
# FA_score                                                           693
# FA_size                                                            825
# FA_method                                                     CAGE_TCs
# FA_ovlp_len                                                        825
# FA_ovlp_pct                                                    24.6048
# FA_encyclopedia                                                 FANTOM
#
# chrom                                                             chr3  \
# start                                                          5062817
# end                                                            5068862
# name                                            ENCODE.3.ENCFF778PVS.8
# score                                                                1
# strand                                                               .
# size                                                              6045
# method                                                   DNase_H3K27ac
# description          Enhancer-like regions using DNase and H3K27ac ...
# assembly                                                          hg19
# biosample_type                                            primary cell
# biosample_term_id                                           CL:0002327
# biosample_term_name                            mammary epithelial cell
# developmental_slims                                       ['ectoderm']
# system_slims                                   ['integumental system']
# organ_slims                                          ['mammary gland']
# encyclopedia                                                    ENCODE
# FA_chrom                                                          chr3
# FA_start                                                       5067974
# FA_end                                                         5068590
# FA_name                                      FANTOM.5.PERMISSIVE.26422
# FA_score                                                           256
# FA_size                                                            616
# FA_method                                                     CAGE_TCs
# FA_ovlp_len                                                        616
# FA_ovlp_pct                                                    10.1902
# FA_encyclopedia                                                 FANTOM
#
# chrom                                                             chr8
# start                                                        126230865
# end                                                          126234434
# name                                            ENCODE.3.ENCFF778PVS.9
# score                                                                1
# strand                                                               .
# size                                                              3569
# method                                                   DNase_H3K27ac
# description          Enhancer-like regions using DNase and H3K27ac ...
# assembly                                                          hg19
# biosample_type                                            primary cell
# biosample_term_id                                           CL:0002327
# biosample_term_name                            mammary epithelial cell
# developmental_slims                                       ['ectoderm']
# system_slims                                   ['integumental system']
# organ_slims                                          ['mammary gland']
# encyclopedia                                                    ENCODE
# FA_chrom                                                          chr8
# FA_start                                                     126231490
# FA_end                                                       126231859
# FA_name                                      FANTOM.5.PERMISSIVE.39851
# FA_score                                                           140
# FA_size                                                            369
# FA_method                                                     CAGE_TCs
# FA_ovlp_len                                                        369
# FA_ovlp_pct                                                     10.339
# FA_encyclopedia                                                 FANTOM

# %%
prefix = None

if prefix:
     print('true')
else:
     print('F')
# Out:
# F

# %%
name = 'ROADMAP.E001.0'
name[8:12]
# Out:
# 'E001'
